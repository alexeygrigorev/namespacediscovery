# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import json
import os
import pickle

from collections import defaultdict
from collections import Counter

from time import time

# %matplotlib inline

import scipy.sparse

# %%
import matplotlib
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'
matplotlib.rc('axes', labelsize='large')

# %%
def id_counter(id_list):
    cnt = Counter()
    for el in id_list:
        cnt[el[u'element']] = el[u'count']
    return cnt

def_black_list = { 'unit', 'units', 'value', 'values', 'axis', 'axes', 'factor', 'factors', 'line', 'lines',
                 'point', 'points', 'number', 'numbers', 'variable', 'variables', 'respect', 'case', 'cases',
                 'vector', 'vectors', 'element', 'elements', 'example', 
                 'integer', 'integers', 'term', 'terms', 'parameter', 'parameters', 'coefficient', 'coefficients',
                 'formula', 'times', 'product', 'matrices', 'expression', 'complex', 'real', 'zeros', 'bits',
                 'sign',
                 'if and only if',
                 'alpha', 'beta', 'gamma', 'delta', 'epsilon', 'zeta', 'eta', 'theta', 'iota', 'kappa', 'lambda', 
                 'mu', 'nu', 'xi', 'omicron', 'pi', 'rho', 'sigma', 'tau', 'upsilon', 'phi', 'chi', 'psi', 'omega'}

def valid_def(definition):
    if len(definition) <= 3:
        return False

    return definition.lower() not in def_black_list

def rel_to_dict(rels):
    res = defaultdict(list)
    for r in rels:
        if not valid_def(r['definition']):
            continue
        res[r['identifier']].append((r['definition'], r['score']))
    return res


doc_categories = defaultdict(set)
category_docs = defaultdict(set)

for line in file('C:/tmp/mlp/category_info_refined.txt'):
    title, cat = line.strip().split('\t')
    title = title.decode('utf-8')
    cat = cat.decode('utf-8')

    # let's also remove all documents from "OTHER" category
    if cat == u'OTHER':
        continue

    doc_categories[title].add(cat) 
    category_docs[cat].add(title)

root = 'C:/tmp/mlp/mlp-output/'

docs = []
titles = []
ids = []
rels = []

empty = 0
small = 0
uncategorized = 0

for f in os.listdir(root): 
    for line in file(root + f):
        doc = json.loads(line)

        title = doc['title']        
        if title not in doc_categories:
            uncategorized = uncategorized + 1
            continue

        if '(disambiguation)' in title:
            continue

        id_bag = id_counter(doc['identifiers'])
        if len(id_bag) <= 1:
            if len(id_bag) == 0:
                empty = empty + 1
            else:
                small = small + 1
            continue

        docs.append(doc)
        titles.append(title)
        ids.append(id_bag)

        id_rels = rel_to_dict(doc['relations'])
        rels.append(id_rels)

print empty, small, uncategorized

N_doc = len(ids)
print N_doc

title_idx = {title: idx for (idx, title) in enumerate(titles)}

for doc, cats in doc_categories.items():
    if doc in title_idx:
        continue

    for cat in cats: 
        category_docs[cat].remove(doc)
    
    del doc_categories[doc]

print len(doc_categories)

doc_categories_list = [doc_categories[doc] for doc in titles]
# Out:
# 0 0 7501
# 22512
# 22512

# %%
import cluster_evaluation
reload(cluster_evaluation)
evaluate = cluster_evaluation.Evaluator(doc_titles=titles, doc_ids=ids, 
                                        doc_ids_definitions=rels, doc_categories=doc_categories_list)

# %% [markdown]
# ## Using MSC and PACS

# %% [markdown]
# ### MSC
#
# Data taken from http://cran.r-project.org/web/classifications/MSC.html

# %%
tree = {}

top_parent = None
parent = None

for line in file('C:/tmp/mlp/msc.txt'):
    if line.startswith('#'):
        continue

    tabs = sum(1 for s in line[:8] if s == ' ') / 4
    code, name = line.strip().split(': ', 1)
    name = name.decode('utf-8')
    name = name.replace('$', '')
    
    if code.endswith('99'):
        # 'Miscellaneous topics' or 'None of the above, but in this section'
        continue
  
    if tabs == 0:
        top_parent = name
        tree[top_parent] = {}
    elif tabs == 1:
        parent = name
        tree[top_parent][parent] = []
    else:
        tree[top_parent][parent].append(name)

# %% [markdown]
# Let's remove categories without subcategories: they anyways are usually precedings or historical or monographs. "Aplications" subcategories don't seem to be very useful - remove as weel. Finally, let's remove some top categories like "general", "History" etc
#
# Some are physics specific that have many common words, so let's remove than and let PACS be used

# %%
del tree['General']
del tree['History and biography']
del tree['Mathematics education']

del tree['Quantum theory']['Axiomatics, foundations, philosophy']
del tree['Quantum theory']['Applications to specific physical systems']
del tree['Quantum theory']['Groups and algebras in quantum theory']

del tree['Partial differential equations']['Equations of mathematical physics and other areas of application']
del tree['Statistics']['Sufficiency and information']
del tree['Functional analysis']['Other (nonclassical) types of functional analysis']
del tree['Functional analysis']['Miscellaneous applications of functional analysis']

# %%
for k_top, top in tree.items():
    for k_2, v in top.items():
        if not v:
            del top[k_2]
        elif k_2 == u'Applications':
            del top[k_2]
        elif 'proceedings' in k_2.lower() or 'conferences' in k_2.lower() or 'collections' in k_2.lower():
            del top[k_2]

# %% [markdown]
# ### PACS
#
# data taken from https://github.com/teefax/pacsparser

# %%
import re

tree_pacs = {}

top_top_parent = None
top_parent = None
parent = None

pacs_file = file('C:/tmp/mlp/pacs.txt')

see_also_re = re.compile('\(see also.+?\)')
for_see_re = re.compile('\(for.+?see.+?\)')
tags_re = re.compile('<[^ ].*?>')

for line in pacs_file:
    if line.startswith('#'):
        continue
    if not line.strip():
        continue

    line = line.strip()
    code = line[0:8]
    if code.strip() == '... ...':
        continue

    if code == 'APPENDIX':
        break
        
    name = line[9:].decode('utf-8').replace('$', '')

    name = see_also_re.sub('', name)
    name = for_see_re.sub('', name)
    name = tags_re.sub('', name)

    codes = code.split('.')
    if len(codes) < 3:
        print code
    is_top_level =  False

    if codes[0].isdigit():
        top_code = int(codes[0])
        is_top_level = (top_code % 10 == 0) & (codes[1] == '00') & (codes[2] == '00')

    if is_top_level:
        top_top_parent = name
        tree_pacs[top_top_parent] = {}
    elif (codes[1] == '00') & (codes[2] == '00'):
        top_parent = name
        tree_pacs[top_top_parent][top_parent] = {}
    elif codes[2][0] in ['+', '-']:
        parent = name
        tree_pacs[top_top_parent][top_parent][parent] = []
    else: # tabs == 0
        tree_pacs[top_top_parent][top_parent][parent].append(name)

# %%
del tree_pacs['GENERAL']

# %%
pacs = {}
for k_0, cat_top in tree_pacs.items():
    for k_1, cat in cat_top.items():
        pacs[k_0 + ' ' + k_1] = cat

# %%
general_pacs = {}
for k_0, cat_top in tree_pacs.items():
    general_pacs[k_0] = {}

    for k_1, cat in cat_top.items():
        desc = []
        for k_2, low_cat in cat.items():
            desc.append(k_2)
            desc.extend(low_cat)
        
        general_pacs[k_0][k_1] = desc

# %% [markdown]
# ### Wikipedia Categories
#
# MSC's "Statistics" category doesn't seem to be good enough - statistical clusters gets mapped to anything else but stats. So let's create a stat category ourselves using wiki categories data

# %%
wiki_tree = {}

narrower = defaultdict(set)
broader = defaultdict(set)

for line in file('C:/tmp/mlp/skos_math_broader.txt'):
    all_categories = line.decode('utf-8').strip().split('\t')
    
    child = all_categories[0]
    broader_list = all_categories[1:]

    for parent in broader_list:
        narrower[parent].add(child)
        broader[child].add(parent)

wiki_stat_category = set()

wiki_stat_category.update(narrower['Statistics'])

for cat in narrower['Statistics']:
    wiki_stat_category.update(narrower[cat])

wiki_tree['Statistics'] = {}
wiki_tree['Statistics']['Wiki statistics'] = wiki_stat_category

# %% [markdown]
# ### ACM Classification Scheme
#
# Can be downloaded from http://www.acm.org/about/class/class/2012 and has parsable skos format http://dl.acm.org/ft_gateway.cfm?id=2371137&ftid=1290922&dwn=1

# %%
import rdflib
from rdflib.namespace import SKOS

import logging
logging.getLogger('rdflib.term').setLevel(logging.ERROR)

# %%
g = rdflib.Graph()
g.load('C:/tmp/mlp/acm_skos_taxonomy.xml')

pref_len = len('file:///C://tmp/mlp/acm_skos_taxonomy.xml')

acm_titles = {}

for s, p, o in g.triples((None, SKOS.prefLabel, None)):
    if o.language != 'en':
        continue
    acm_titles[s[pref_len:]] = o.value

broader = defaultdict(set)
narrower = defaultdict(set)

for s, _, o in g.triples((None, SKOS.broader, None)):
    subj_title = acm_titles[s[pref_len:]]
    obj_title = acm_titles[o[pref_len:]]
    broader[subj_title].add(obj_title)
    narrower[obj_title].add(subj_title)

top_level = ['Hardware', 'Computer systems organization', 'Networks', 'Software and its engineering',
             'Theory of computation', 'Information systems', 'Security and privacy', 'Human-centered computing',
             'Computing methodologies']

acm_tree = {}

def dfs(result, cat):
    result.append(cat)
    if cat in narrower:
        for n_cat in narrower[cat]:
            dfs(result, n_cat)
    return result

for most_top in top_level:
    acm_tree[most_top] = {}
    for cat in narrower[most_top]:
        acm_tree[most_top][cat] = dfs([], cat)

# %% [markdown]
# ## Category Index
#
# Now we can build an index from these categories - and can find the most similar category fro each cluster
#
# But first, let's merge MCS and PACS and other categories

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
snowball_stemmer = SnowballStemmer('english')

from sklearn.feature_extraction.text import TfidfVectorizer

# %%
all_cat_tree = defaultdict(dict)

for d in [tree, general_pacs, acm_tree]: #wiki_tree
    for k, dict_inner in d.items():
        all_cat_tree[k].update(dict_inner)

# %%
all_categories = []
all_categories_idx = {}

english_sw = set(stopwords.words('english') + 
                 ['etc', 'given', 'method', 'methods', 'theory', 'problem', 'problems', 'model', 'models'] + 
                 ['section'] + ['must', 'also'])

cnt = 0

for k_top, top in all_cat_tree.items():
    for k_2, v in top.items():
        top = ' '.join([k_top] * 3)
        document = top + ' ' + k_2 + ' ' + ' '.join(v)
        tokens = word_tokenize(document)
        tokens = [t.lower() for t in tokens if t.isalpha()]
        tokens = [t for t in tokens if t not in english_sw]
        # tokens = [snowball_stemmer.stem(t) for t in tokens]
        all_categories.append(tokens)
        all_categories_idx[cnt] = (k_top, k_2)
        cnt = cnt + 1


def identity(lst): return lst
category_vectorizer = TfidfVectorizer(analyzer=identity).fit(all_categories)

cat_index = category_vectorizer.transform(all_categories)
cat_index
# Out:
# <533x5321 sparse matrix of type '<type 'numpy.float64'>'
# 	with 19661 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### Indexing Clusters
#
# Now let's apply the same transformation to clusters

# %%
cluster_assignment = pickle.load(file('C:/tmp/mlp/namespaces/best414.bin'))

# %%
descriptions = evaluate.high_purity_clusters(cluster_assignment, threshold=0.8, all_categories=1, min_size=3)
desc_ids = [d['cluster'] for d in descriptions]
len(desc_ids)
# Out:
# 414

# %%
def counter_to_string(cnt, repeat=1):
    if repeat:
        return ' '.join([(word + ' ') * cnt for word, cnt in cl_cats.items()])
    else:
        return ' '.join(cnt.keys())

def all_definitions(clustering, cluster_index):
    indices, = np.where(clustering == cluster_index)
    
    all_defs = []
    for idx in indices: 
        idx = int(idx)
        for lst in rels[idx].values():
            for d, _ in lst:
                all_defs.extend(d.split())
    return all_defs

clusters_representation = []

for cl_id in desc_ids:
    cl_titles, cl_cats = evaluate.cluster_details(cluster_assignment, cl_id)
    #defs = all_definitions(clustering, cl_id)
    document = ' '.join(cl_titles) + ' ' + counter_to_string(cl_cats) #+ ' '.join(defs)
    tokens = word_tokenize(document)
    tokens = [t.lower() for t in tokens if t.isalpha()]
    tokens = [t for t in tokens if t not in english_sw]
    # tokens = [snowball_stemmer.stem(t) for t in tokens]
    clusters_representation.append(tokens)
    
clus_index = category_vectorizer.transform(clusters_representation)
clus_index
# Out:
# <414x5321 sparse matrix of type '<type 'numpy.float64'>'
# 	with 10564 stored elements in Compressed Sparse Row format>

# %% [markdown]
# Now calculate cosine between VS of hierarchy and clusters

# %%
clus_cat_sim = (clus_index * cat_index.T).toarray()
best_similarity = clus_cat_sim.max(axis=1)
clus_cat_assignment = clus_cat_sim.argmax(axis=1)
clus_cat_assignment
# Out:
# array([400, 406, 441, 345, 489, 455, 173,  24, 367, 250,  71, 347, 406,
#         27, 382, 399, 347, 419, 274, 527,  45, 455, 485,  24, 489, 370,
#        307,   5,  73, 113,  73,  53, 138, 370, 442, 362, 370, 385, 343,
#        478, 527,  25, 417, 329, 102, 311, 526, 410, 354, 195, 432,  64,
#        370,  53,   8, 278, 397, 475, 409, 489, 417,  13, 530, 343, 324,
#        274, 201, 422, 432, 262,  73, 201, 362, 101, 112, 326, 526,  67,
#         51, 409, 432, 324,  81, 527, 281, 417, 528, 419, 262, 424, 274,
#        304, 217, 517, 417, 384, 324, 489,   2, 364, 103, 445, 106, 307,
#         51, 483, 195, 112,  84, 196, 379, 240, 266, 103, 354, 380, 347,
#        267, 311,  67, 419, 274,   2, 475,  81, 264,  51, 113,   1,  51,
#        112, 311, 513, 445, 173, 343, 362, 188,  85, 267,  25, 372, 193,
#        452, 324,  63, 442, 372, 324,  73, 484, 103, 324, 490,  73, 372,
#        341, 330, 341, 175, 398, 478,  64, 480, 422, 332, 343, 330, 526,
#        406, 201,  97, 429, 390, 417, 323, 173, 387, 440, 377, 423, 372,
#        419, 419, 321, 172, 370, 324, 400, 256, 376, 442, 406, 432, 264,
#        455,  24,  97,  71, 307, 432, 439, 400, 530,  39,   2, 172, 376,
#        201, 311, 475,  73,  81,  51, 274, 304, 398,  64, 475, 513, 125,
#        270, 504,   2, 324, 196, 223, 481, 425, 162,  63, 307, 311,  63,
#         19, 366, 530, 108, 100, 103,  73, 327, 274, 417,  13, 412, 362,
#        489, 311, 406, 489, 410, 201, 424, 274, 201, 347, 168,  72, 270,
#        195, 372, 442, 455, 104, 421, 384, 307, 334, 419, 113, 130, 342,
#         67,  73, 185, 195, 411, 103,  39, 324, 274, 329, 406, 196, 475,
#         39,  67, 347, 300,  73, 249,  13, 401,   2, 277, 302, 300, 400,
#        307, 196, 475, 312, 465,  51, 256,  39, 195, 528, 347, 201, 417,
#        212, 425, 304, 342, 475, 277,  64, 109,   2, 112,  84, 298, 362,
#        285, 377, 125, 478,  69, 526, 264, 101, 103, 347, 274, 442, 201,
#        103, 455,  83,   1, 252, 422, 484,  17, 324, 116,  34,   9, 417,
#        112,  67, 253, 347, 277, 240, 201,  18,  80, 195, 470, 263, 307,
#         81,   1,  67, 112, 175, 358, 324, 330,   9,   2, 173, 422, 476,
#        527, 347,  63, 324, 455, 429, 274, 173, 240,  97,  73, 370, 419,
#        410,  67,  51, 195, 196, 274,  71, 440,   2, 406, 116, 399, 399,
#        216,  64, 162, 400, 422, 478, 386, 425, 277, 325, 374], dtype=int64)

# %%
clus_id = 10
evaluate.print_cluster(cluster_assignment, desc_ids[clus_id])
# Out:
# cluster 217, size: 5
# - Stirling's approximation (categories: Mathematical analysis, Mathematical theorems, Number theory, Complex analysis, Special functions, ...) π B_k d Π s k j m Γ O n p S t N_+ y x c_n z
# - Error function (categories: Complex analysis, Special functions, Types of functions, Analytic functions, Real analysis, ...) Γ E_n τ Φ γ ζ π σ E_0 D c_k c_m O N Q P F_1 w d g k j m l n q p erf erfc t R_N x z
# - Clausen function (categories: Special functions, Analytic number theory, Algebraic number theory, Zeta and L-functions) Sl_4 Γ Sl_1 Sl_2 Sl_3 Λ Li_2 Cl_4 Cl_5 Cl_6 Cl_1 Cl_2 Cl_3 β Gl_m η ζ θ ψ_m π Li_n G φ S_z L R Ti_2 Z B_j C_z d B_n Cl_s k j m l n q p s t y x z
# - Properties of polynomial roots (categories: Mathematical analysis, Abstract algebra, Fields of mathematics, Functions and mappings, Numerical analysis, ...) σ b_0 b_1 b_m d_1 N_n ζ z_j z_n π C B D R_p M O Q P R x_± z_1 c b d g h k j m l n q p t x z
# - Struve function (categories: Combinatorics, Complex analysis, Lie groups, Special functions, Types of functions) Y_α Γ E_n α H_n ν π L_α τ F O L_ν d g H_α k m n t y x z
#
# common terms: (π d k m n t x z)
# top categories: (Special functions, 4), (Complex analysis, 3), (Types of functions, 2), (Mathematical analysis, 2), (Analytic functions, 2)
# purity: 0.800
# relations:
#      B_k: (bernoulli number: 0.87), (euler -- maclaurin formula: 0.81)
#      B_n: (bernoulli numbers: 0.96), (relation: 0.86)
#      C: (field: 0.99), (complex numbers: 0.87)
#      Cl_2: (clausen: 0.95)
#      E_n: (weber functions: 0.96), (generalised error: 0.93), (vice: 0.92), (graph: 0.81)
#      G: (catalans constant: 0.93), (constants: 0.93)
#      O: (next term: 0.87)
#      P: (root: 0.82)
#      R: (real number: 0.96), (coefficient index: 0.87)
#      b: (root: 2.58)
#      c: (euclidean division of polynomials: 0.83)
#      d_1: (bounds: 0.89), (proof: 0.86)
#      erf: (real axis: 0.91), (fact: 0.82)
#      erfc: (complementary error function: 0.89), (good approximation: 0.89), (arithmetic underflow: 0.87)
#      k: (multiplicity*: 1.61), (coefficient index: 0.96), (stirling numbers of the first kind: 0.83)
#      m: (positive integer: 0.96)
#      n: (roots: 1.94), (look: 1.81), (non-negative integer: 1.72), (order: 0.96), (degree: 0.92), (division: 0.92), (increases: 0.91), (continuously: 0.88), (unity: 0.87), (struve: 0.83), (polynomial: 0.82)
#      p: (roots: 0.87), (bounds: 0.82), (states: 0.81)
#      t: (series: 0.93), (stirling: 0.89), (riemann-siegel theta function: 0.84)
#      x: (bernoulli polynomials: 0.96), (dummy variable: 0.96), (power series expansion: 0.83), (distance: 0.82), (mean value: 0.82)
#      x_±: (above formula: 0.95), (roots: 0.89)
#      y: (quantity: 0.87)
#      z: (complex number*: 2.64), (arguments: 0.95)
#      Γ: (gamma function: 0.89)
#      Λ: (lobachevsky: 0.95)
#      Φ: (cumulative distribution*: 1.77)
#      α: (complex number: 0.96), (order: 0.86)
#      ζ: (proof*: 1.84), (zeta function: 0.93)
#      θ: (polynomials: 0.89), (mathematics: 0.86), (clausen: 0.83)
#      π: (red curve: 0.99), (multiples: 0.87)
#      σ: (standard deviation: 1.94), (variance: 1.90), (mean density*: 1.70), (expected value: 0.89), (errors: 0.87), (probability: 0.86), (normal distribution: 0.84), (distance: 0.81)

# %% [markdown]
# ## Building a hierarhcy
#
# Let's build a hierarchy:

# %%
namespaces = defaultdict(list)
namespace_name = []

for idx in range(len(desc_ids)):
    cat_id = clus_cat_assignment[idx]
    desc = descriptions[idx]

    score = best_similarity[idx]
    common_keywords = set(clusters_representation[idx]) & set(all_categories[cat_id])

    parent_cat, namespace_cat = all_categories_idx[cat_id]
    if score <= 0.2 or len(common_keywords) == 1:
        parent_cat = 'OTHER'

    namespaces[parent_cat].append((namespace_cat, score, desc, common_keywords))
    namespace_name.append((desc['cluster'], (parent_cat, namespace_cat)))

namespaces = sorted(namespaces.items())

# %%
class Namespace():

    _parent = None
    _name = None
    _identifiers = None
    _children = None
    _relations = None
    _wiki_cats = None

    _cluster_id = None

    def __init__(self, name, parent=None):
        self._name = name
        self._children = []

        if parent:
            self._parent = parent
            self._parent._children.append(self)

    def set_wiki_categories(self, wiki_cats):
        self._wiki_cats = wiki_cats
        
    def most_common_wiki_cat(self):
        if self._wiki_cats:
            return self._wiki_cats.most_common(1)[0]
        else:
            return None

    def set_relations(self, relations):
        self._relations = relations

    def set_additional_info(self, cluster_id, purity, matching_score, matching_terms):
        self._cluster_id = cluster_id
        self._purity = purity
        self._matching_score = matching_score
        self._matching_terms = matching_terms

    def print_ns(self, indend=0, print_rels=0):
        indend_str = ' ' * (4 * indend)
        print indend_str, 'Category: %s' % self._name
        if self._wiki_cats:
            print indend_str, '          wiki categories:', 
            print ', '.join('%s (%d)' % (cat, cnt) for cat, cnt in self._wiki_cats.most_common(3))
        if self._cluster_id:
            print indend_str, '          cluster_id: %d (matching score: %0.2f, purity: %0.2f)' % \
                                    (self._cluster_id, self._matching_score, self._purity)
            print indend_str, '          common:', ' '.join(self._matching_terms)

        if print_rels and self._relations:
            for id, def_list in self._relations:
                print indend_str, '-',
                print evaluate._string_def_list(id, def_list) 
        
        print 
        for child in self._children:
            child.print_ns(indend+1, print_rels=print_rels)
            print
    
    def __repr__(self):
        return self._name

# %%
ROOT = Namespace('ROOT')

for parent_cat, groups in namespaces:
    parent_namespace = Namespace(parent_cat, ROOT)

    for cat, score, desc, common in groups:
        ns = Namespace(cat, parent_namespace)
        ns.set_wiki_categories(desc['all_categories'])

        wiki_category = ns.most_common_wiki_cat()
        cluster_id = desc['cluster']
        ns.set_additional_info(cluster_id, desc['purity'], score, common)

        all_def = evaluate.find_all_def(cluster_assignment, cluster_id) 
        all_items = sorted(all_def.items())
        ns.set_relations(all_items)

# %%
ROOT.print_ns(print_rels=0)
# Out:
#  Category: ROOT
#
#      Category: ATOMIC AND MOLECULAR PHYSICS
#
#          Category: Atomic properties and interactions with photons
#                    wiki categories: Atomic physics (3), Quantum mechanics (3), Atomic, molecular, and optical physics (3)
#                    cluster_id: 4338 (matching score: 0.34, purity: 1.00)
#                    common: optical molecular physics atomic
#
#
#
#      Category: Algebraic geometry
#
#          Category: Computational aspects in algebraic geometry
#                    wiki categories: Sheaf theory (3), Theorems in geometry (3), Theorems in algebraic geometry (3)
#                    cluster_id: 86 (matching score: 0.60, purity: 1.00)
#                    common: surfaces geometry varieties algebraic
#
#
#          Category: Computational aspects in algebraic geometry
#                    wiki categories: Algebraic geometry (4), Algebraic varieties (3), Manifolds (3)
#                    cluster_id: 2977 (matching score: 0.59, purity: 0.80)
#                    common: surfaces geometry varieties algebraic
#
#
#          Category: Computational aspects in algebraic geometry
#                    wiki categories: Algebraic geometry (4), Geometry (3), Abstract algebra (3)
#                    cluster_id: 4062 (matching score: 0.70, purity: 1.00)
#                    common: geometry algebraic varieties curves
#
#
#          Category: Algebraic groups
#                    wiki categories: Group theory (3), Algebraic structures (2), Finite groups (1)
#                    cluster_id: 4347 (matching score: 0.53, purity: 1.00)
#                    common: group classical geometry actions algebraic groups
#
#
#          Category: Algebraic groups
#                    wiki categories: Group theory (3), Finite groups (2), Clifford algebras (2)
#                    cluster_id: 4742 (matching score: 0.40, purity: 1.00)
#                    common: geometry algebraic group groups
#
#
#          Category: Surfaces and higher-dimensional varieties
#                    wiki categories: Algebraic varieties (3), Threefolds (2), Surfaces (1)
#                    cluster_id: 8693 (matching score: 0.59, purity: 1.00)
#                    common: surfaces algebraic varieties
#
#
#          Category: Computational aspects in algebraic geometry
#                    wiki categories: Algebraic geometry (4), Algebraic topology (3), Topological methods of algebraic geometry (3)
#                    cluster_id: 8755 (matching score: 0.53, purity: 0.80)
#                    common: geometry algebraic
#
#
#          Category: Computational aspects in algebraic geometry
#                    wiki categories: Algebraic geometry (4), Abstract algebra (3), Geometry (2)
#                    cluster_id: 9034 (matching score: 0.59, purity: 1.00)
#                    common: geometry algebraic varieties
#
#
#
#      Category: Algebraic topology
#
#          Category: Fiber spaces and bundles
#                    wiki categories: Differential geometry (5), Fiber bundles (4), Topology (4)
#                    cluster_id: 3975 (matching score: 0.43, purity: 1.00)
#                    common: fiber space characteristic bundles algebraic classes groups homotopy topology
#
#
#          Category: Spectral sequences
#                    wiki categories: Abstract algebra (3), Homological algebra (3), Algebraic topology (3)
#                    cluster_id: 4089 (matching score: 0.52, purity: 1.00)
#                    common: spectral serre sequences topology algebraic
#
#
#          Category: Applied homological algebra and category theory
#                    wiki categories: Continuous mappings (3), Algebraic topology (3), Homotopy theory (3)
#                    cluster_id: 9619 (matching score: 0.48, purity: 1.00)
#                    common: category homological abstract algebra algebraic sets simplicial homotopy topology
#
#
#
#      Category: Associative rings and algebras
#
#          Category: Modules, bimodules and ideals
#                    wiki categories: Abstract algebra (4), Module theory (4), Ring theory (4)
#                    cluster_id: 415 (matching score: 0.26, purity: 1.00)
#                    common: simple module
#
#
#
#      Category: Biology and other natural sciences
#
#          Category: Mathematical biology in general
#                    wiki categories: Evidence-based practices (3), Public health (3), Epidemiology (3)
#                    cluster_id: 3442 (matching score: 0.36, purity: 1.00)
#                    common: sciences biology statistics related biostatistics
#
#
#          Category: Genetics and population dynamics
#                    wiki categories: Population genetics (4), Genetics (4), Subfields and areas of study related to evolutionary biology (3)
#                    cluster_id: 5054 (matching score: 0.42, purity: 0.80)
#                    common: dna biology genetics related population
#
#
#
#      Category: CONDENSED MATTER: ELECTRONIC STRUCTURE, ELECTRICAL, MAGNETIC, AND OPTICAL PROPERTIES
#
#          Category: Magnetic properties and materials
#                    wiki categories: Magnetism (3), Electromagnetism (3), Magnetostatics (1)
#                    cluster_id: 4404 (matching score: 0.26, purity: 1.00)
#                    common: condensed magnetic matter magnetism materials magnets
#
#
#          Category: Optical properties, condensed-matter spectroscopy and other interactions of radiation and particles with condensed matter
#                    wiki categories: Materials science (3), Condensed matter physics (3), Electromagnetism (2)
#                    cluster_id: 6897 (matching score: 0.28, purity: 1.00)
#                    common: condensed solid magnetic matter state materials systems quantum electronic semiconductors
#
#
#          Category: Magnetic properties and materials
#                    wiki categories: Magnetism (4), Materials science (3), Condensed matter physics (3)
#                    cluster_id: 7297 (matching score: 0.36, purity: 1.00)
#                    common: condensed magnetization ferromagnetic ordering magnetic matter magnetism materials systems
#
#
#          Category: Superconductivity
#                    wiki categories: Superconductivity (4), Josephson effect (4), Materials science (3)
#                    cluster_id: 8386 (matching score: 0.26, purity: 1.00)
#                    common: phases junction josephson superconductivity condensed effect matter materials
#
#
#
#      Category: CONDENSED MATTER: STRUCTURAL, MECHANICAL, AND THERMAL PROPERTIES
#
#          Category: Mechanical and acoustical properties of condensed matter
#                    wiki categories: Mechanical engineering (3), Technology systems (3), Mechanisms (3)
#                    cluster_id: 7107 (matching score: 0.25, purity: 1.00)
#                    common: ratio systems mechanical
#
#
#          Category: Surfaces and interfaces; thin films and nanosystems (structure and nonelectronic properties)
#                    wiki categories: Measurement (3), Electromagnetism (3), Materials science (2)
#                    cluster_id: 7646 (matching score: 0.20, purity: 1.00)
#                    common: scanning condensed force magnetic microscopy matter materials systems quantum physical
#
#
#
#      Category: Calculus of variations and optimal control; optimization
#
#          Category: Manifolds
#                    wiki categories: Calculus of variations (4), Mathematical analysis (4), Optimization in vector spaces (4)
#                    cluster_id: 4649 (matching score: 0.24, purity: 0.80)
#                    common: calculus variations principles analysis optimization physics
#
#
#
#      Category: Category theory; homological algebra
#
#          Category: Categories with structure
#                    wiki categories: Category theory (3), Multilinear algebra (3), Monoidal categories (3)
#                    cluster_id: 56 (matching score: 0.75, purity: 1.00)
#                    common: category monoidal algebra symmetric closed categories
#
#
#          Category: Homological algebra
#                    wiki categories: Category theory (4), Abstract algebra (4), Mathematical structures (3)
#                    cluster_id: 786 (matching score: 0.48, purity: 0.80)
#                    common: category algebra simplicial homological
#
#
#          Category: Categories and geometry
#                    wiki categories: Category theory (13), Abstract algebra (10), Functions and mappings (5)
#                    cluster_id: 2245 (matching score: 0.63, purity: 0.81)
#                    common: category functors homological geometry abstract algebra algebraic categories manifolds
#
#
#          Category: Categories and geometry
#                    wiki categories: Category theory (4), Mathematical structures (3), Abstract algebra (3)
#                    cluster_id: 2894 (matching score: 0.57, purity: 1.00)
#                    common: category abstract categories algebra
#
#
#          Category: Homological algebra
#                    wiki categories: Abstract algebra (3), Ring theory (2), Category theory (1)
#                    cluster_id: 3297 (matching score: 0.44, purity: 1.00)
#                    common: category homological algebra
#
#
#          Category: Abelian categories
#                    wiki categories: Physics (3), Gravitation (2), Statics (2)
#                    cluster_id: 4094 (matching score: 0.27, purity: 1.00)
#                    common: categories theories
#
#
#          Category: Homological algebra
#                    wiki categories: Algebra (4), Linear algebra (4), Category theory (1)
#                    cluster_id: 4486 (matching score: 0.53, purity: 1.00)
#                    common: category theories objects homological algebra
#
#
#          Category: Homological algebra
#                    wiki categories: Abstract algebra (3), Module theory (3), Ring theory (3)
#                    cluster_id: 5839 (matching score: 0.41, purity: 1.00)
#                    common: category homological algebra
#
#
#          Category: Abelian categories
#                    wiki categories: SI units (5), SI derived units (5), Wikipedia categories named after scientists (2)
#                    cluster_id: 9352 (matching score: 0.27, purity: 0.83)
#                    common: derived categories
#
#
#
#      Category: Classical thermodynamics, heat transfer
#
#          Category: Thermodynamics and heat transfer
#                    wiki categories: Thermodynamics (3), People associated with energy (1), History of physics (1)
#                    cluster_id: 58 (matching score: 0.38, purity: 1.00)
#                    common: thermodynamics chemistry
#
#
#          Category: Thermodynamics and heat transfer
#                    wiki categories: Atmospheric thermodynamics (3), Meteorology (2), Branches of thermodynamics (2)
#                    cluster_id: 545 (matching score: 0.33, purity: 1.00)
#                    common: chemical thermodynamics mass
#
#
#          Category: Thermodynamics and heat transfer
#                    wiki categories: Thermodynamics (4), Temperature (3), Physical chemistry (3)
#                    cluster_id: 1358 (matching score: 0.22, purity: 1.00)
#                    common: chemical transfer heat chemistry thermodynamics
#
#
#          Category: Thermodynamics and heat transfer
#                    wiki categories: Thermodynamics (3), Heat transfer (2), Forms of energy (2)
#                    cluster_id: 2123 (matching score: 0.58, purity: 1.00)
#                    common: chemical transfer heat chemistry thermodynamics
#
#
#          Category: Thermodynamics and heat transfer
#                    wiki categories: Thermodynamics (3), Physical chemistry (2), People associated with energy (1)
#                    cluster_id: 5495 (matching score: 0.30, purity: 1.00)
#                    common: chemical thermodynamics chemistry
#
#
#          Category: Thermodynamics and heat transfer
#                    wiki categories: Physics (5), Thermodynamics (4), Physical chemistry (4)
#                    cluster_id: 5539 (matching score: 0.30, purity: 0.83)
#                    common: chemical transfer heat chemistry thermodynamics
#
#
#
#      Category: Combinatorics
#
#          Category: Graph theory
#                    wiki categories: Graph theory (6), Graph theory objects (4), Mathematical relations (2)
#                    cluster_id: 992 (matching score: 0.43, purity: 1.00)
#                    common: perfect coloring combinatorics graph graphs isomorphism algorithms
#
#
#          Category: Graph theory
#                    wiki categories: Graph theory (9), Combinatorics (3), Graph theory objects (3)
#                    cluster_id: 3171 (matching score: 0.50, purity: 0.90)
#                    common: coloring combinatorics graph trees graphs algorithms topological geometric intersection
#
#
#          Category: Algebraic combinatorics
#                    wiki categories: Abstract algebra (3), Ring theory (2), Group theory (1)
#                    cluster_id: 4574 (matching score: 0.26, purity: 1.00)
#                    common: combinatorics algebraic regular group
#
#
#
#      Category: Computer science
#
#          Category: Theory of data
#                    wiki categories: Information theory (7), Information (6), Telecommunications engineering (6)
#                    cluster_id: 391 (matching score: 0.36, purity: 1.00)
#                    common: information computer communication science
#
#
#          Category: Theory of data
#                    wiki categories: Discrete mathematics (6), Coding theory (6), Information theory (6)
#                    cluster_id: 975 (matching score: 0.37, purity: 1.00)
#                    common: information computer coding data science
#
#
#          Category: Discrete mathematics in relation to computer science
#                    wiki categories: Graph theory (4), Fields of mathematics (3), Combinatorics (3)
#                    cluster_id: 1074 (matching score: 0.54, purity: 1.00)
#                    common: combinatorics science discrete computer graph mathematics
#
#
#          Category: Computing methodologies and applications
#                    wiki categories: Digital geometry (3), Mathematical morphology (3), Computer graphics (3)
#                    cluster_id: 1474 (matching score: 0.40, purity: 1.00)
#                    common: mathematical geometry image processing computer graphics
#
#
#          Category: Discrete mathematics in relation to computer science
#                    wiki categories: Metalogic (3), Grammar (3), Formal sciences (3)
#                    cluster_id: 1761 (matching score: 0.38, purity: 1.00)
#                    common: combinatorics science discrete computer words mathematics
#
#
#          Category: Theory of data
#                    wiki categories: Information theory (4), Coding theory (4), Encodings (3)
#                    cluster_id: 1892 (matching score: 0.33, purity: 1.00)
#                    common: information computer coding data science
#
#
#          Category: Algorithms
#                    wiki categories: Computational complexity theory (5), Analysis of algorithms (4), Theoretical computer science (4)
#                    cluster_id: 1927 (matching score: 0.54, purity: 0.83)
#                    common: science computer algorithms analysis
#
#
#          Category: Discrete mathematics in relation to computer science
#                    wiki categories: Graph theory (4), Applied mathematics (2), Computational science (2)
#                    cluster_id: 3899 (matching score: 0.47, purity: 0.80)
#                    common: combinatorics science computer mathematics graph
#
#
#          Category: Computing methodologies and applications
#                    wiki categories: Computer graphics algorithms (3), Computer graphics (3), Signal processing (3)
#                    cluster_id: 4681 (matching score: 0.43, purity: 1.00)
#                    common: image computer processing graphics
#
#
#          Category: Computing methodologies and applications
#                    wiki categories: Computer graphics algorithms (3), Computer graphics (3), Signal processing (3)
#                    cluster_id: 5207 (matching score: 0.41, purity: 1.00)
#                    common: geometry image computer processing graphics
#
#
#          Category: Algorithms
#                    wiki categories: Algorithms on strings (6), Substring indices (4), Database index techniques (4)
#                    cluster_id: 7395 (matching score: 0.44, purity: 1.00)
#                    common: science computer algorithms
#
#
#          Category: Discrete mathematics in relation to computer science
#                    wiki categories: Metalogic (3), Grammar (3), Formal sciences (3)
#                    cluster_id: 7836 (matching score: 0.47, purity: 1.00)
#                    common: combinatorics science computer words mathematics
#
#
#          Category: Theory of data
#                    wiki categories: Encodings (3), Information theory (3), Coding theory (3)
#                    cluster_id: 8808 (matching score: 0.27, purity: 1.00)
#                    common: information computer coding data science
#
#
#
#      Category: Computer systems organization
#
#          Category: Real-time systems
#                    wiki categories: Computer languages (3), Type systems (3), Data types (3)
#                    cluster_id: 1313 (matching score: 0.37, purity: 1.00)
#                    common: languages computer systems architecture
#
#
#
#      Category: Computing methodologies
#
#          Category: Machine learning
#                    wiki categories: Machine learning (4), Learning (4), Artificial intelligence (4)
#                    cluster_id: 2892 (matching score: 0.73, purity: 1.00)
#                    common: learning neural machine statistical modeling networks
#
#
#          Category: Machine learning
#                    wiki categories: Statistical data types (3), Multivariate statistics (3), Statistical classification (2)
#                    cluster_id: 4866 (matching score: 0.37, purity: 1.00)
#                    common: kernel statistical classification support analysis machine vector algorithms learning regression machines linear
#
#
#
#      Category: Convex and discrete geometry
#
#          Category: Polytopes and polyhedra
#                    wiki categories: Polyhedra (4), Prismatoid polyhedra (3), Pyramids and bipyramids (2)
#                    cluster_id: 9682 (matching score: 0.34, purity: 1.00)
#                    common: linear geometry polyhedra programming convex polytopes
#
#
#
#      Category: Differential geometry
#
#          Category: Local differential geometry
#                    wiki categories: Riemannian geometry (3), Smooth manifolds (1), Riemannian manifolds (1)
#                    cluster_id: 1053 (matching score: 0.50, purity: 1.00)
#                    common: riemannian geometry differential
#
#
#          Category: Global differential geometry
#                    wiki categories: Theoretical physics (3), Differential topology (2), Mathematical analysis (2)
#                    cluster_id: 1711 (matching score: 0.35, purity: 1.00)
#                    common: surfaces geometry physics differential complex geometric structures manifolds
#
#
#          Category: Classical differential geometry
#                    wiki categories: Differential geometry (4), Riemannian geometry (2), Differential topology (2)
#                    cluster_id: 2234 (matching score: 0.60, purity: 0.80)
#                    common: surfaces space geometry differential curvature analysis geometric
#
#
#          Category: Classical differential geometry
#                    wiki categories: Differential geometry (3), Geometric shapes (2), Curves (2)
#                    cluster_id: 2492 (matching score: 0.60, purity: 1.00)
#                    common: geometry geometric differential curves analysis
#
#
#          Category: Classical differential geometry
#                    wiki categories: Mathematical analysis (3), Complex analysis (2), Surfaces (1)
#                    cluster_id: 3453 (matching score: 0.33, purity: 1.00)
#                    common: surfaces geometry differential minimal analysis
#
#
#          Category: Symplectic geometry, contact geometry
#                    wiki categories: Dynamical systems (3), Hamiltonian mechanics (2), Symplectic geometry (2)
#                    cluster_id: 5267 (matching score: 0.32, purity: 1.00)
#                    common: geometry differential maps symplectic poisson physics
#
#
#          Category: Classical differential geometry
#                    wiki categories: Differential geometry (4), Curves (3), Analytic geometry (3)
#                    cluster_id: 5302 (matching score: 0.58, purity: 1.00)
#                    common: surfaces geometry differential curvature curves analysis geometric
#
#
#          Category: Classical differential geometry
#                    wiki categories: Surfaces (4), Systolic geometry (4), Riemannian geometry (4)
#                    cluster_id: 6325 (matching score: 0.68, purity: 1.00)
#                    common: surfaces classical geometry differential curves euclidean geometric conformal
#
#
#          Category: Global differential geometry
#                    wiki categories: Abstract algebra (3), Riemannian geometry (3), Algebraic geometry (3)
#                    cluster_id: 7884 (matching score: 0.46, purity: 1.00)
#                    common: riemannian geometry structures differential physics spin manifolds
#
#
#          Category: Classical differential geometry
#                    wiki categories: Differential geometry (4), Mathematical analysis (4), Differential topology (4)
#                    cluster_id: 7885 (matching score: 0.47, purity: 1.00)
#                    common: tensor geometry differential analysis vector geometric
#
#
#          Category: Classical differential geometry
#                    wiki categories: Differential geometry (7), Differential topology (7), Theoretical physics (6)
#                    cluster_id: 7959 (matching score: 0.57, purity: 0.88)
#                    common: surfaces differential classical geometry affine analysis vector geometric
#
#
#
#      Category: ELECTROMAGNETISM, OPTICS, ACOUSTICS, HEAT TRANSFER, CLASSICAL MECHANICS, AND FLUID DYNAMICS
#
#          Category: Classical mechanics of discrete systems
#                    wiki categories: Mechanics (3), Physics (3), Classical mechanics (3)
#                    cluster_id: 1889 (matching score: 0.31, purity: 1.00)
#                    common: mechanics classical particle motion forces mechanical
#
#
#          Category: Acoustics
#                    wiki categories: Physical quantities (3), Acoustics (3), Sound measurements (3)
#                    cluster_id: 2393 (matching score: 0.47, purity: 1.00)
#                    common: sound mechanics acoustics measurements fluid dynamics physical
#
#
#          Category: Classical mechanics of discrete systems
#                    wiki categories: Physics (5), Mechanics (4), Classical mechanics (3)
#                    cluster_id: 2755 (matching score: 0.30, purity: 1.00)
#                    common: mechanics calculus linear classical motion optimization kinematics dynamics variational
#
#
#          Category: Continuum mechanics of solids
#                    wiki categories: Mechanics (8), Continuum mechanics (7), Materials science (6)
#                    cluster_id: 3040 (matching score: 0.46, purity: 1.00)
#                    common: mechanics continuum classical elasticity analysis mechanical plates
#
#
#          Category: Classical mechanics of discrete systems
#                    wiki categories: Mechanics (3), Physics (3), Mechanical engineering (2)
#                    cluster_id: 4775 (matching score: 0.33, purity: 1.00)
#                    common: mechanics motion particle classical mechanical
#
#
#          Category: Acoustics
#                    wiki categories: Applied and interdisciplinary physics (3), Sound (2), Fluid dynamics (2)
#                    cluster_id: 7631 (matching score: 0.32, purity: 1.00)
#                    common: sound acoustics fluid music dynamics optics physical
#
#
#          Category: Optics
#                    wiki categories: Optics (3), Natural philosophy (2), Applied and interdisciplinary physics (2)
#                    cluster_id: 8003 (matching score: 0.26, purity: 1.00)
#                    common: spectral electromagnetic laser propagation electrodynamics medical coherence radiation resolution physics applications frequency atomic spectroscopy measurement tomography optical optics techniques
#
#
#          Category: Heat transfer
#                    wiki categories: Heat transfer (3), Fluid dynamics (3), Thermodynamics (3)
#                    cluster_id: 8519 (matching score: 0.49, purity: 1.00)
#                    common: mechanics conduction transfer fluid heat convection dynamics
#
#
#          Category: Classical mechanics of discrete systems
#                    wiki categories: Physics (4), Mechanics (4), Classical mechanics (4)
#                    cluster_id: 8609 (matching score: 0.33, purity: 0.80)
#                    common: mechanics computational classical general motion conservation kinematics systems mechanical momentum
#
#
#
#      Category: Field theory and polynomials
#
#          Category: Differential and difference algebra
#                    wiki categories: Numerical analysis (4), Abstract algebra (4), Algebra (4)
#                    cluster_id: 228 (matching score: 0.48, purity: 1.00)
#                    common: abstract difference polynomials algebra
#
#
#          Category: Differential and difference algebra
#                    wiki categories: Module theory (3), Abstract algebra (3), Ring theory (3)
#                    cluster_id: 359 (matching score: 0.31, purity: 1.00)
#                    common: abstract algebra
#
#
#          Category: Differential and difference algebra
#                    wiki categories: Abstract algebra (4), Ring theory (3), Algebra (2)
#                    cluster_id: 2566 (matching score: 0.36, purity: 0.80)
#                    common: abstract algebra
#
#
#          Category: Differential and difference algebra
#                    wiki categories: Numerical analysis (4), Abstract algebra (4), Algebra (4)
#                    cluster_id: 5649 (matching score: 0.50, purity: 0.80)
#                    common: abstract polynomials algebra
#
#
#          Category: Differential and difference algebra
#                    wiki categories: Algebra (3), Linear algebra (2), Vectors (2)
#                    cluster_id: 6823 (matching score: 0.32, purity: 1.00)
#                    common: field abstract algebra
#
#
#          Category: Differential and difference algebra
#                    wiki categories: Abstract algebra (4), Commutative algebra (2), Algebraic geometry (2)
#                    cluster_id: 7402 (matching score: 0.47, purity: 1.00)
#                    common: field abstract polynomials algebra
#
#
#          Category: Differential and difference algebra
#                    wiki categories: Abstract algebra (3), Ring theory (2), Numerical analysis (1)
#                    cluster_id: 7890 (matching score: 0.47, purity: 1.00)
#                    common: field abstract polynomials algebra
#
#
#          Category: Differential and difference algebra
#                    wiki categories: Linear algebra (3), Spectral theory (1), Abstract algebra (1)
#                    cluster_id: 8391 (matching score: 0.38, purity: 1.00)
#                    common: abstract differential polynomials algebra
#
#
#          Category: Differential and difference algebra
#                    wiki categories: Multilinear algebra (3), Algebra (2), Linear algebra (2)
#                    cluster_id: 8847 (matching score: 0.35, purity: 1.00)
#                    common: abstract differential algebra
#
#
#
#      Category: Fluid mechanics
#
#          Category: Biological fluid mechanics
#                    wiki categories: Fluid mechanics (4), Soft matter (2), Gases (2)
#                    cluster_id: 381 (matching score: 0.50, purity: 1.00)
#                    common: mechanics fluid
#
#
#          Category: Biological fluid mechanics
#                    wiki categories: Fluid dynamics (4), Fluid mechanics (3), Computational fluid dynamics (2)
#                    cluster_id: 1551 (matching score: 0.48, purity: 1.00)
#                    common: mechanics fluid
#
#
#          Category: Biological fluid mechanics
#                    wiki categories: Fluid dynamics (3), Computational fluid dynamics (1), Differential equations (1)
#                    cluster_id: 2002 (matching score: 0.47, purity: 1.00)
#                    common: mechanics fluid flows
#
#
#          Category: Biological fluid mechanics
#                    wiki categories: Fluid dynamics (5), Fluid mechanics (4), Dynamics (4)
#                    cluster_id: 2677 (matching score: 0.50, purity: 0.83)
#                    common: mechanics fluid
#
#
#          Category: Compressible fluids and gas dynamics, general
#                    wiki categories: Thermodynamics (3), Gases (2), Statistical mechanics (2)
#                    cluster_id: 3086 (matching score: 0.25, purity: 1.00)
#                    common: mechanics equation gas
#
#
#          Category: Biological fluid mechanics
#                    wiki categories: Fluid dynamics (5), Fluid mechanics (5), Dynamics (5)
#                    cluster_id: 4796 (matching score: 0.55, purity: 0.83)
#                    common: mechanics fluid
#
#
#          Category: Foundations, constitutive equations, rheology
#                    wiki categories: Materials science (3), Building engineering (3), Applied and interdisciplinary physics (3)
#                    cluster_id: 4928 (matching score: 0.35, purity: 1.00)
#                    common: mechanics fluid classical fluids
#
#
#          Category: Biological fluid mechanics
#                    wiki categories: Fluid dynamics (4), Fluid mechanics (3), Aerospace engineering (3)
#                    cluster_id: 5324 (matching score: 0.49, purity: 0.80)
#                    common: mechanics fluid
#
#
#          Category: Biological fluid mechanics
#                    wiki categories: Fluid dynamics (10), Waves (8), Physical oceanography (8)
#                    cluster_id: 5619 (matching score: 0.45, purity: 1.00)
#                    common: mechanics water fluid
#
#
#          Category: Foundations, constitutive equations, rheology
#                    wiki categories: Liquids (3), Non-Newtonian fluids (3), Fluid mechanics (3)
#                    cluster_id: 5692 (matching score: 0.73, purity: 1.00)
#                    common: mechanics fluids fluid
#
#
#          Category: Biological fluid mechanics
#                    wiki categories: Fluid dynamics (3), Dimensionless numbers of fluid mechanics (3), Dimensionless numbers (3)
#                    cluster_id: 7892 (matching score: 0.54, purity: 1.00)
#                    common: mechanics fluid
#
#
#          Category: Biological fluid mechanics
#                    wiki categories: Fluid dynamics (5), Fluid mechanics (4), Physics (3)
#                    cluster_id: 9006 (matching score: 0.42, purity: 0.83)
#                    common: mechanics fluid
#
#
#          Category: Biological fluid mechanics
#                    wiki categories: Units of velocity (4), Airspeed (4), Aviation (4)
#                    cluster_id: 9258 (matching score: 0.22, purity: 0.80)
#                    common: mechanics fluid
#
#
#
#      Category: Fourier analysis
#
#          Category: Fourier analysis in several variables
#                    wiki categories: Signal processing (5), Electrical engineering (3), Fourier analysis (3)
#                    cluster_id: 3934 (matching score: 0.30, purity: 0.83)
#                    common: function functions series harmonic analysis spaces fourier
#
#
#          Category: Fourier analysis in several variables
#                    wiki categories: Mathematical analysis (9), Harmonic analysis (5), Multivariable calculus (4)
#                    cluster_id: 4579 (matching score: 0.41, purity: 0.82)
#                    common: functions singular series harmonic analysis transforms integrals fourier
#
#
#          Category: Fourier analysis in several variables
#                    wiki categories: Mathematical analysis (3), Theorems in analysis (2), Mathematical theorems (2)
#                    cluster_id: 9056 (matching score: 0.44, purity: 1.00)
#                    common: series fourier harmonic analysis
#
#
#
#      Category: Functional analysis
#
#          Category: Distributions, generalized functions, distribution spaces
#                    wiki categories: Probability distributions (4), Exponential family distributions (3), Continuous distributions (2)
#                    cluster_id: 2472 (matching score: 0.53, purity: 1.00)
#                    common: analytic distribution distributions generalized
#
#
#          Category: Distributions, generalized functions, distribution spaces
#                    wiki categories: Continuous distributions (4), Probability distributions (4), Generalized hyperbolic distributions (2)
#                    cluster_id: 8442 (matching score: 0.53, purity: 0.80)
#                    common: distribution distributions generalized
#
#
#          Category: Distributions, generalized functions, distribution spaces
#                    wiki categories: Continuous distributions (4), Probability distributions (4), Extreme value data (1)
#                    cluster_id: 9045 (matching score: 0.57, purity: 0.80)
#                    common: functions functional analysis generalized distribution distributions
#
#
#
#      Category: Functions of a complex variable
#
#          Category: Miscellaneous topics of analysis in the complex domain
#                    wiki categories: Complex analysis (7), Mathematical analysis (5), Theorems in complex analysis (3)
#                    cluster_id: 1116 (matching score: 0.36, purity: 1.00)
#                    common: functions integral integration analysis analytic cauchy complex
#
#
#          Category: Miscellaneous topics of analysis in the complex domain
#                    wiki categories: Complex analysis (4), Theorems in complex analysis (3), Theorems in analysis (3)
#                    cluster_id: 2496 (matching score: 0.37, purity: 1.00)
#                    common: analytic functions complex analysis
#
#
#          Category: Geometric function theory
#                    wiki categories: Cartography (3), Coordinate systems (3), Cartographic projections (3)
#                    cluster_id: 8702 (matching score: 0.20, purity: 1.00)
#                    common: complex conformal mapping mappings
#
#
#
#      Category: GEOPHYSICS, ASTRONOMY, AND ASTROPHYSICS
#
#          Category: Stars
#                    wiki categories: Astronomical catalogues (52), Bayer objects (48), Constellations (48)
#                    cluster_id: 1150 (matching score: 0.63, purity: 0.98)
#                    common: planetary sequence variables planets proper star ceti binary giant nebulae cygni circumstellar systems stars majoris multiple dwarf extrasolar spectroscopic beta objects delta variable alpha types g subgiant lyrae disks binaries
#
#
#          Category: Stars
#                    wiki categories: Astronomical catalogues of stars (5), Henry Draper Catalogue objects (5), Hipparcos (4)
#                    cluster_id: 1589 (matching score: 0.61, purity: 1.00)
#                    common: binary multiple stars planetary subgiant sequence spectroscopic objects systems planets star binaries types dwarf
#
#
#          Category: Stars
#                    wiki categories: Main sequence stars (3), Constellations (3), Pictor (constellation) (2)
#                    cluster_id: 1813 (matching score: 0.58, purity: 1.00)
#                    common: extrasolar planetary star dwarf objects sequence disks circumstellar beta stars systems planets astronomy types nebulae
#
#
#          Category: Solid Earth physics
#                    wiki categories: Geophysics (3), Seismology (3), Subfields of geology (2)
#                    cluster_id: 3949 (matching score: 0.31, purity: 1.00)
#                    common: mechanics mathematical geology solid body geophysics seismology waves earth seismic physics
#
#
#          Category: Stars
#                    wiki categories: Stellar astronomy (3), Stars (3), Bodies of the Solar System (2)
#                    cluster_id: 4515 (matching score: 0.53, purity: 1.00)
#                    common: sequence stellar stars astrophysics astronomy structure
#
#
#          Category: Stars
#                    wiki categories: Constellations (4), Gliese and GJ objects (4), Astronomical catalogues of stars (4)
#                    cluster_id: 4645 (matching score: 0.62, purity: 1.00)
#                    common: spectral planetary planets star degenerate sequence luminosity variables majoris objects systems stars variable white class types dwarf
#
#
#          Category: Hydrospheric and atmospheric geophysics
#                    wiki categories: Physical chemistry (3), Chemical kinetics (2), Organic chemistry (1)
#                    cluster_id: 5066 (matching score: 0.25, purity: 1.00)
#                    common: chemical pressure chemistry temperature physical
#
#
#          Category: Hydrospheric and atmospheric geophysics
#                    wiki categories: Oceanography (3), Physical geography (3), Earth sciences (3)
#                    cluster_id: 7497 (matching score: 0.22, purity: 1.00)
#                    common: layers mechanics layer ecology oceanography meteorology water oceans earth hydrography boundary dynamics transport physical
#
#
#          Category: Solid Earth physics
#                    wiki categories: Petroleum geology (3), Seismology measurement (3), Petroleum (3)
#                    cluster_id: 8923 (matching score: 0.26, purity: 1.00)
#                    common: equations seismology geology
#
#
#          Category: Hydrospheric and atmospheric geophysics
#                    wiki categories: Thermodynamics (4), Equilibrium chemistry (4), Analytical chemistry (4)
#                    cluster_id: 9645 (matching score: 0.26, purity: 1.00)
#                    common: analysis chemical analytical chemistry physics physical
#
#
#
#      Category: Game theory, economics, social and behavioral sciences
#
#          Category: Mathematical economics
#                    wiki categories: Consumer theory (4), Consumerism (3), Household behavior and family economics (3)
#                    cluster_id: 637 (matching score: 0.42, purity: 1.00)
#                    common: mathematical behavior decision economics monetary economic statistical demand consumer utility
#
#
#          Category: Mathematical economics
#                    wiki categories: Fields of finance (3), Risk (3), Mathematical finance (3)
#                    cluster_id: 698 (matching score: 0.21, purity: 1.00)
#                    common: mathematical risk economics mathematics insurance finance
#
#
#          Category: Mathematical economics
#                    wiki categories: Financial economics (4), Investment (4), Mathematical finance (3)
#                    cluster_id: 1652 (matching score: 0.29, purity: 0.80)
#                    common: mathematical finance fundamental economics analysis cost economic statistical mathematics investment market risk
#
#
#          Category: Mathematical economics
#                    wiki categories: Discrete mathematics (3), Management (2), Control theory (2)
#                    cluster_id: 3432 (matching score: 0.26, purity: 1.00)
#                    common: mathematical decision economics sciences game mathematics consumer utility
#
#
#          Category: Mathematical economics
#                    wiki categories: Microeconomics (3), Social economy (2), Socioeconomics (2)
#                    cluster_id: 3580 (matching score: 0.54, purity: 1.00)
#                    common: finance decision economics sciences methodology economic behavior behavioral mathematics consumer taxation market social
#
#
#          Category: Mathematical economics
#                    wiki categories: Macroeconomics and monetary economics (6), Money (6), Economics (6)
#                    cluster_id: 4768 (matching score: 0.52, purity: 1.00)
#                    common: economics finance basic monetary sciences economic social
#
#
#          Category: Mathematical economics
#                    wiki categories: Economics (3), Production and manufacturing (1), Labor economics (1)
#                    cluster_id: 6259 (matching score: 0.45, purity: 1.00)
#                    common: economics labor sciences production demand social
#
#
#          Category: Mathematical economics
#                    wiki categories: Derivatives (finance) (4), Financial markets (3), Financial economics (3)
#                    cluster_id: 9058 (matching score: 0.23, purity: 1.00)
#                    common: mathematical finance economics economic mathematics investment
#
#
#
#      Category: General topology
#
#          Category: Connections with other structures, applications
#                    wiki categories: General topology (3), Topology (3), Fields of mathematics (2)
#                    cluster_id: 642 (matching score: 0.48, purity: 1.00)
#                    common: fields topological general systems sets dynamics structures topology
#
#
#          Category: Connections with other structures, applications
#                    wiki categories: General topology (3), Topology (3), Set theory (2)
#                    cluster_id: 2802 (matching score: 0.52, purity: 1.00)
#                    common: topology set descriptive topological general
#
#
#          Category: Connections with other structures, applications
#                    wiki categories: Topology (3), Mathematical structures (2), Space (2)
#                    cluster_id: 6204 (matching score: 0.46, purity: 1.00)
#                    common: set fields topological general structures topology
#
#
#          Category: Generalities
#                    wiki categories: Topology (5), General topology (4), Topology of function spaces (1)
#                    cluster_id: 8172 (matching score: 0.55, purity: 1.00)
#                    common: spaces functions set topology general
#
#
#          Category: Generalities
#                    wiki categories: Topology (4), Fields of mathematics (2), General topology (2)
#                    cluster_id: 9401 (matching score: 0.47, purity: 0.80)
#                    common: closure functions topology structures general
#
#
#
#      Category: Geometry
#
#          Category: Analytic and descriptive geometry
#                    wiki categories: Triangle geometry (4), Euclidean plane geometry (3), Theorems in geometry (2)
#                    cluster_id: 616 (matching score: 0.53, purity: 0.80)
#                    common: geometry euclidean
#
#
#          Category: Distance geometry
#                    wiki categories: Differential geometry (3), Multilinear algebra (2), Theoretical physics (2)
#                    cluster_id: 1061 (matching score: 0.48, purity: 1.00)
#                    common: geometry differential general
#
#
#          Category: Analytic and descriptive geometry
#                    wiki categories: Quadrilaterals (5), Polygons (5), Physical quantities (2)
#                    cluster_id: 2316 (matching score: 0.35, purity: 1.00)
#                    common: geometry euclidean
#
#
#          Category: Distance geometry
#                    wiki categories: Geometry (3), Metric geometry (3), Properties of topological spaces (1)
#                    cluster_id: 2625 (matching score: 0.58, purity: 1.00)
#                    common: geometry distance
#
#
#          Category: Distance geometry
#                    wiki categories: Finsler geometry (4), Riemannian geometry (3), Differential topology (3)
#                    cluster_id: 2877 (matching score: 0.59, purity: 1.00)
#                    common: geometry differential
#
#
#          Category: Analytic and descriptive geometry
#                    wiki categories: Ratios (4), History of geometry (4), Mathematical constants (4)
#                    cluster_id: 4620 (matching score: 0.36, purity: 0.80)
#                    common: geometry algebraic number classification euclidean
#
#
#          Category: Distance geometry
#                    wiki categories: Geometry (3), Symplectic topology (1), Lipschitz maps (1)
#                    cluster_id: 4751 (matching score: 0.62, purity: 1.00)
#                    common: geometry differential
#
#
#          Category: Analytic and descriptive geometry
#                    wiki categories: Combinatorics (3), Discrete mathematics (2), Fields of mathematics (1)
#                    cluster_id: 5099 (matching score: 0.30, purity: 1.00)
#                    common: geometry euclidean number analytic
#
#
#          Category: Distance geometry
#                    wiki categories: Metric geometry (4), Differential geometry (4), Riemannian geometry (3)
#                    cluster_id: 5100 (matching score: 0.59, purity: 0.80)
#                    common: geometry differential
#
#
#          Category: Distance geometry
#                    wiki categories: Riemannian geometry (3), Differential geometry (3), Metric geometry (3)
#                    cluster_id: 5515 (matching score: 0.50, purity: 1.00)
#                    common: geometry differential general
#
#
#          Category: Analytic and descriptive geometry
#                    wiki categories: Polygons (5), Quadrilaterals (4), Euclidean plane geometry (2)
#                    cluster_id: 6033 (matching score: 0.35, purity: 0.83)
#                    common: geometry euclidean physics groups classical
#
#
#          Category: Analytic and descriptive geometry
#                    wiki categories: Euclidean plane geometry (3), Triangle geometry (3), Inequalities (2)
#                    cluster_id: 7151 (matching score: 0.56, purity: 1.00)
#                    common: geometry euclidean classical
#
#
#          Category: Geometric order structures
#                    wiki categories: Curves (4), Manifolds (3), Geometric shapes (3)
#                    cluster_id: 7232 (matching score: 0.50, purity: 1.00)
#                    common: geometry geometric curves
#
#
#          Category: Analytic and descriptive geometry
#                    wiki categories: Group theory (3), Aesthetics (2), Abstract algebra (2)
#                    cluster_id: 8608 (matching score: 0.41, purity: 1.00)
#                    common: classical euclidean geometry one algebraic groups physics
#
#
#
#      Category: Geophysics
#
#          Category: Computational methods
#                    wiki categories: Meteorology (3), Weather (3), Aviation meteorology (3)
#                    cluster_id: 9487 (matching score: 0.21, purity: 1.00)
#                    common: dynamics meteorology atmospheric
#
#
#
#      Category: Group theory and generalizations
#
#          Category: Connections with homological algebra and category theory
#                    wiki categories: Group theory (4), Abstract algebra (3), Metric geometry (2)
#                    cluster_id: 1328 (matching score: 0.51, purity: 0.80)
#                    common: category group groups algebra
#
#
#          Category: Connections with homological algebra and category theory
#                    wiki categories: Group theory (3), Abstract algebra (2), Metric geometry (2)
#                    cluster_id: 2746 (matching score: 0.45, purity: 1.00)
#                    common: group groups algebra
#
#
#          Category: Connections with homological algebra and category theory
#                    wiki categories: Group theory (3), Abstract algebra (2), Metric geometry (2)
#                    cluster_id: 4764 (matching score: 0.41, purity: 1.00)
#                    common: group groups algebra
#
#
#          Category: Connections with homological algebra and category theory
#                    wiki categories: Group theory (4), Abstract algebra (3), Metric geometry (3)
#                    cluster_id: 4861 (matching score: 0.29, purity: 1.00)
#                    common: group groups algebra
#
#
#          Category: Connections with homological algebra and category theory
#                    wiki categories: Group theory (4), Abstract algebra (2), Metric geometry (2)
#                    cluster_id: 6748 (matching score: 0.47, purity: 1.00)
#                    common: group groups algebra
#
#
#          Category: Connections with homological algebra and category theory
#                    wiki categories: Group theory (9), Abstract algebra (4), Metric geometry (4)
#                    cluster_id: 7228 (matching score: 0.44, purity: 1.00)
#                    common: group groups algebra
#
#
#          Category: Special aspects of infinite or finite groups
# ...
#                    wiki categories: Quantum mechanics (5), Modern physics (4), Philosophy of physics (4)
#                    cluster_id: 8354 (matching score: 0.30, purity: 1.00)
#                    common: mechanics mathematical quantum
#
#
#          Category: General mathematical topics and methods in quantum theory
#                    wiki categories: Quantum mechanics (4), Quantum field theory (4), Theoretical physics (4)
#                    cluster_id: 8648 (matching score: 0.30, purity: 0.80)
#                    common: mathematical mechanics dirac geometry differential quantum equations
#
#
#          Category: General mathematical topics and methods in quantum theory
#                    wiki categories: Quantum mechanics (3), Mechanics (2), Particle physics (2)
#                    cluster_id: 9145 (matching score: 0.30, purity: 1.00)
#                    common: mechanics quantum
#
#
#          Category: Quantum field theory; related classical field theories
#                    wiki categories: Quantum field theory (4), Quantum mechanics (4), Theoretical physics (4)
#                    cluster_id: 9495 (matching score: 0.46, purity: 1.00)
#                    common: quantum field group renormalization
#
#
#
#      Category: Real functions
#
#          Category: Polynomials, rational functions
#                    wiki categories: Polynomials (3), Orthogonal polynomials (2), Special functions (2)
#                    cluster_id: 1306 (matching score: 0.54, purity: 1.00)
#                    common: analytic functions polynomials
#
#
#          Category: Functions of one variable
#                    wiki categories: Integral calculus (4), Science-related lists (4), Mathematics-related lists (4)
#                    cluster_id: 1911 (matching score: 0.28, purity: 1.00)
#                    common: calculus elementary functions special integrals
#
#
#          Category: Miscellaneous topics
#                    wiki categories: Complex analysis (5), Mathematical analysis (3), Theorems in analysis (2)
#                    cluster_id: 7042 (matching score: 0.33, purity: 0.83)
#                    common: real functions spaces analysis
#
#
#          Category: Miscellaneous topics
#                    wiki categories: Mathematical analysis (4), Integral calculus (2), Combinatorics (2)
#                    cluster_id: 7587 (matching score: 0.32, purity: 0.80)
#                    common: real calculus functions analysis
#
#
#          Category: Miscellaneous topics
#                    wiki categories: Complex analysis (5), Types of functions (3), Riemann surfaces (3)
#                    cluster_id: 8417 (matching score: 0.45, purity: 1.00)
#                    common: real functions analysis
#
#
#          Category: Miscellaneous topics
#                    wiki categories: Mathematical analysis (3), Mathematical structures (2), Types of functions (2)
#                    cluster_id: 9651 (matching score: 0.35, purity: 1.00)
#                    common: real functions analysis
#
#
#
#      Category: Relativity and gravitational theory
#
#          Category: Computational methods
#                    wiki categories: General relativity (7), Density (5), Astrophysics (5)
#                    cluster_id: 1513 (matching score: 0.52, purity: 1.00)
#                    common: relativity special
#
#
#          Category: Computational methods
#                    wiki categories: Theory of relativity (3), Philosophy of physics (2), Special relativity (2)
#                    cluster_id: 3274 (matching score: 0.47, purity: 1.00)
#                    common: relativity special
#
#
#          Category: Unified, higher-dimensional and super field theories
#                    wiki categories: Theories of gravitation (4), Gravitation (3), Scientific theories (3)
#                    cluster_id: 3981 (matching score: 0.39, purity: 0.80)
#                    common: relativity cosmology theories
#
#
#          Category: Computational methods
#                    wiki categories: Theoretical physics (3), Theory of relativity (2), Special relativity (2)
#                    cluster_id: 4359 (matching score: 0.46, purity: 1.00)
#                    common: relativity special
#
#
#          Category: Computational methods
#                    wiki categories: Force (5), Special relativity (5), Physics (5)
#                    cluster_id: 6516 (matching score: 0.47, purity: 1.00)
#                    common: relativity special
#
#
#          Category: Computational methods
#                    wiki categories: Electromagnetism (3), Force (2), Special relativity (2)
#                    cluster_id: 8112 (matching score: 0.23, purity: 1.00)
#                    common: relativity special
#
#
#          Category: Computational methods
#                    wiki categories: Physics (4), Special relativity (3), Theory of relativity (2)
#                    cluster_id: 8704 (matching score: 0.33, purity: 0.80)
#                    common: relativity special
#
#
#
#      Category: Sequences, series, summability
#
#          Category: General summability methods
#                    wiki categories: Sequences and series (5), Mathematical structures (2), Combinatorics (2)
#                    cluster_id: 739 (matching score: 0.42, purity: 0.83)
#                    common: series summability matrix sequences
#
#
#
#      Category: Several complex variables and analytic spaces
#
#          Category: Differential operators in several variables
#                    wiki categories: Complex analysis (4), Several complex variables (4), Functions and mappings (3)
#                    cluster_id: 4973 (matching score: 0.58, purity: 0.80)
#                    common: variables complex several analysis
#
#
#
#      Category: Software and its engineering
#
#          Category: Software notations and tools
#                    wiki categories: Metalogic (3), Syntax (logic) (3), Grammar (3)
#                    cluster_id: 8189 (matching score: 0.44, purity: 1.00)
#                    common: software language compiler programming syntax languages engineering logic compilers formal
#
#
#
#      Category: Special functions (33-XX deals with the properties of functions as functions)
#
#          Category: Other special functions
#                    wiki categories: Special functions (4), Complex analysis (3), Types of functions (2)
#                    cluster_id: 217 (matching score: 0.55, purity: 0.80)
#                    common: functions special properties gamma
#
#
#          Category: Other special functions
#                    wiki categories: Types of functions (3), Analytic number theory (2), Complex analysis (2)
#                    cluster_id: 4591 (matching score: 0.55, purity: 1.00)
#                    common: functions special elliptic
#
#
#          Category: Hypergeometric functions
#                    wiki categories: Special hypergeometric functions (3), Combinatorics (3), Hypergeometric functions (3)
#                    cluster_id: 5665 (matching score: 0.78, purity: 1.00)
#                    common: functions orthogonal hypergeometric polynomials elliptic special
#
#
#          Category: Elementary classical functions
#                    wiki categories: Special functions (4), Complex analysis (3), Types of functions (2)
#                    cluster_id: 7805 (matching score: 0.51, purity: 0.80)
#                    common: functions special exponential integral incomplete integrals elementary gamma
#
#
#          Category: Other special functions
#                    wiki categories: Special functions (3), Gamma and related functions (2), Complex analysis (2)
#                    cluster_id: 9281 (matching score: 0.56, purity: 1.00)
#                    common: functions special gamma
#
#
#
#      Category: Statistical mechanics, structure of matter
#
#          Category: Equilibrium statistical mechanics
#                    wiki categories: Statistical theory (5), Asymptotic analysis (3), Asymptotic statistical theory (3)
#                    cluster_id: 2015 (matching score: 0.34, purity: 1.00)
#                    common: stochastic statistical
#
#
#          Category: Applications to specific types of physical systems
#                    wiki categories: Physics (3), Thermodynamics (2), Materials science (2)
#                    cluster_id: 7099 (matching score: 0.33, purity: 1.00)
#                    common: mechanics specific matter materials systems statistical physical
#
#
#          Category: Equilibrium statistical mechanics
#                    wiki categories: Condensed matter physics (4), Statistical mechanics (3), Conformal field theory (2)
#                    cluster_id: 7511 (matching score: 0.32, purity: 1.00)
#                    common: mechanics group renormalization matter phenomena phase critical systems statistical quantum transitions
#
#
#
#      Category: Statistics
#
#          Category: Linear inference, regression
#                    wiki categories: Statistics (4), Data analysis (4), Estimation theory (4)
#                    cluster_id: 1448 (matching score: 0.45, purity: 1.00)
#                    common: statistics linear analysis regression
#
#
#          Category: Linear inference, regression
#                    wiki categories: Statistics (17), Econometrics (16), Statistical data types (15)
#                    cluster_id: 5389 (matching score: 0.40, purity: 0.85)
#                    common: statistics inference linear analysis generalized variance regression
#
#
#          Category: Linear inference, regression
#                    wiki categories: Statistics (3), Data analysis (3), Estimation theory (3)
#                    cluster_id: 6934 (matching score: 0.41, purity: 1.00)
#                    common: statistics linear analysis regression
#
#
#          Category: Survival analysis and censored data
#                    wiki categories: Branches of psychology (3), Educational psychology (3), Educational assessment and evaluation (3)
#                    cluster_id: 8082 (matching score: 0.27, purity: 1.00)
#                    common: statistics testing estimation
#
#
#          Category: Nonparametric inference
#                    wiki categories: Statistics (3), Statistical theory (3), Statistical deviation and dispersion (2)
#                    cluster_id: 8246 (matching score: 0.34, purity: 1.00)
#                    common: functions statistics inference regression estimation
#
#
#          Category: Nonparametric inference
#                    wiki categories: Statistics (4), Inference (1), Prediction (1)
#                    cluster_id: 8733 (matching score: 0.43, purity: 1.00)
#                    common: tolerance distribution statistics inference
#
#
#
#      Category: Systems theory; control
#
#          Category: General
#                    wiki categories: Control theory (5), Cybernetics (5), Systems theory (5)
#                    cluster_id: 925 (matching score: 0.62, purity: 1.00)
#                    common: control systems
#
#
#          Category: General
#                    wiki categories: Coordinate systems (4), Cartography (4), Conceptual systems (4)
#                    cluster_id: 3767 (matching score: 0.31, purity: 1.00)
#                    common: mathematical systems
#
#
#          Category: Stochastic systems and control
#                    wiki categories: Control theory (3), Robot control (2), Signal processing (2)
#                    cluster_id: 3775 (matching score: 0.47, purity: 1.00)
#                    common: control systems learning stochastic optimal estimation
#
#
#          Category: General
#                    wiki categories: Systems theory (3), Control theory (3), Cybernetics (3)
#                    cluster_id: 7786 (matching score: 0.43, purity: 1.00)
#                    common: control system systems
#
#
#          Category: General
#                    wiki categories: Coordinate systems (3), Cartography (3), Conceptual systems (3)
#                    cluster_id: 9598 (matching score: 0.30, purity: 1.00)
#                    common: mathematical systems
#
#
#
#      Category: THE PHYSICS OF ELEMENTARY PARTICLES AND FIELDS
#
#          Category: Specific theories and interaction models; particle systematics
#                    wiki categories: Quantum field theory (3), Nuclear physics (2), Force (2)
#                    cluster_id: 5128 (matching score: 0.30, purity: 1.00)
#                    common: electroweak interaction particle field standard particles elementary quantum beyond physics
#
#
#
#      Category: Theory of computation
#
#          Category: Models of computation
#                    wiki categories: Models of computation (3), Formal methods (3), Theory of computation (3)
#                    cluster_id: 2431 (matching score: 0.54, purity: 1.00)
#                    common: computability abstract machines computation turing
#
#
#          Category: Computational complexity and cryptography
#                    wiki categories: Computational complexity theory (3), Mathematical logic (2), Structural complexity theory (2)
#                    cluster_id: 2500 (matching score: 0.51, purity: 1.00)
#                    common: complexity computational systems logic
#
#
#          Category: Formal languages and automata theory
#                    wiki categories: Theory of computation (6), Automata (computation) (5), Automata theory (5)
#                    cluster_id: 4143 (matching score: 0.60, purity: 0.86)
#                    common: language tree automata computation infinite formal
#
#
#          Category: Design and analysis of algorithms
#                    wiki categories: Graph algorithms (8), Operations research (6), Combinatorial optimization (6)
#                    cluster_id: 4436 (matching score: 0.40, purity: 0.80)
#                    common: mathematical network algorithm graph analysis optimization algorithms mixed
#
#
#          Category: Design and analysis of algorithms
#                    wiki categories: Optimization algorithms and methods (4), Mathematical optimization (4), Algorithms (4)
#                    cluster_id: 4744 (matching score: 0.64, purity: 1.00)
#                    common: mathematical optimization algorithms algorithm
#
#
#          Category: Formal languages and automata theory
#                    wiki categories: Automata theory (4), Automata (computation) (4), Theory of computation (4)
#                    cluster_id: 7735 (matching score: 0.68, purity: 1.00)
#                    common: languages automata computation language formal
#
#
#
#      Category: Topological groups, Lie groups
#
#          Category: Lie groups
#                    wiki categories: Mechanics (5), Symmetry (5), Representation theory of groups (5)
#                    cluster_id: 796 (matching score: 0.41, purity: 0.83)
#                    common: lie representation physics groups fields
#
#
#          Category: Lie groups
#                    wiki categories: Representation theory of Lie groups (4), Representation theory (3), Representation theory of Lie algebras (2)
#                    cluster_id: 1709 (matching score: 0.63, purity: 1.00)
#                    common: lie linear verma groups representation algebras
#
#
#          Category: Noncompact transformation groups
#                    wiki categories: Group theory (4), Algebraic structures (3), Abstract algebra (2)
#                    cluster_id: 2199 (matching score: 0.52, purity: 0.80)
#                    common: lie group topological automorphisms groups structures
#
#
#          Category: Lie groups
#                    wiki categories: Lie groups (4), Group theory (3), Topological groups (3)
#                    cluster_id: 3025 (matching score: 0.74, purity: 1.00)
#                    common: lie group fields topological algebraic groups representation algebras
#
#
#          Category: Lie groups
#                    wiki categories: Lie algebras (3), Lie groups (2), Nonassociative algebras (2)
#                    cluster_id: 5419 (matching score: 0.72, purity: 1.00)
#                    common: lie linear nilpotent groups algebras solvable properties
#
#
#          Category: Lie groups
#                    wiki categories: Lie algebras (4), Properties of Lie algebras (2), Lie groups (2)
#                    cluster_id: 7661 (matching score: 0.70, purity: 1.00)
#                    common: lie algebras semisimple properties groups

# %%
evaluate.print_cluster(cluster_assignment, 2892)
# Out:
# cluster 2892, size: 4
# - Early stopping (categories: Machine learning, Cybernetics, Artificial intelligence, Mathematical modeling, Networks, ...) L_2 E_z x_i y_i ρ E f_ρ H R Y X Z γ_t d f m n f_t t y x z
# - Stability (learning theory) (categories: Machine learning, Artificial intelligence, Learning, Cognition, Behavior, ...) E_z x_m f_S o P_S E_S x_1 y_m β δ z_i z_m C E H L O S V Y X Z Z_m z_1 d f k m l y_1 n y x z
# - Leave one out error (categories: Machine learning, Artificial intelligence, Learning) E_z x_m f_S o P_S y_m β δ z_i z_m V E F L S x_1 Y X Z Z_m z_1 f m l y_1 n y x z
# - Statistical learning theory (categories: Machine learning, Artificial intelligence, Learning) x Z p d f H z γ y_1 n Θ y_n S R y_i V Y X θ y f_S
#
# common terms: (z f n y x Y X Z)
# top categories: (Machine learning, 4), (Learning, 4), (Artificial intelligence, 4), (Neural networks, 1), (Computational neuroscience, 1)
# purity: 1.000
# relations:
#      E: (unknown probability measure: 0.83)
#      H: (hypothesis space*: 5.61), (hilbert: 0.95), (kernel: 0.89), (vc-dimension: 0.88)
#      L: (learning map: 0.94)
#      L_2: (loss: 0.99), (lboost: 0.89), (method: 0.83)
#      S: (training: 2.63), (learning: 0.95), (size: 0.82)
#      V: (loss function*: 5.62), (hypothesis: 0.85)
#      X: (input space*: 1.90), (vector space: 0.83)
#      Y: (vector space*: 1.63), (output space: 0.95), (samples: 0.89), (inputs: 0.87)
#      Z: (training set: 0.81), (labels: 0.81)
#      Z_m: (mapping: 0.93)
#      d: (vc-dimension: 0.99), (hypothesis space: 0.83), (training examples: 0.83)
#      f: (algorithm*: 1.73), (hypothesis: 1.66), (possible function: 0.99), (member: 0.89)
#      f_S: (empirical risk: 0.83)
#      f_t: (empirical risk: 0.89), (population iteration: 0.86)
#      f_ρ: (regression function: 0.95)
#      m: (size: 3.80), (training sets*: 2.46)
#      n: (samples: 0.99), (training examples: 0.94), (bousquet: 0.87), (probability distribution: 0.83), (algorithm: 0.83)
#      p: (degree: 0.99), (exponentials: 0.95), (polynomial: 0.89)
#      x: (conditional distribution: 0.95)
#      y: (actual value: 0.99)
#      y_i: (output: 0.89), (training data: 0.89)
#      Θ: (heaviside: 0.89), (step function: 0.83)
#      β: (uniform stability*: 5.68), (algorithm: 4.15), (probabilistic version: 0.85)
#      γ_t: (step size: 0.99)
#      ρ: (unknown probability measure: 1.81)

# %%
namespace_name[0]
# Out:
# (24,
#  (u'Numerical analysis',
#   u'Mathematical programming, optimization and variational techniques'))

# %%
top_namespaces = set()
for (p, c), t in Counter([(p, c) for id, (p, c) in namespace_name]).most_common(15):
    print p + ': ' + c, t
    top_namespaces.add((p, c))
# Out:
# Fluid mechanics: Biological fluid mechanics 10
# Partial differential equations: Close-to-elliptic equations 9
# Field theory and polynomials: Differential and difference algebra 9
# Game theory, economics, social and behavioral sciences: Mathematical economics 8
# Probability theory and stochastic processes: Foundations of probability theory 8
# Mathematical logic and foundations: General logic 7
# Group theory and generalizations: Connections with homological algebra and category theory 7
# Geometry: Analytic and descriptive geometry 7
# OTHER: Properties of specific nuclei listed by mass ranges (an additional heading must be chosen with these entries, where the given mass number limits are, to some degree, arbitrary) 7
# Probability theory and stochastic processes: Distribution theory 7
# Optics, electromagnetic theory: General 7
# Differential geometry: Classical differential geometry 7
# Numerical analysis: Numerical linear algebra 7
# Quantum theory: General mathematical topics and methods in quantum theory 7
# OTHER: Computational methods 6

# %%
top_ns = defaultdict(list)

for id, pair in namespace_name:
    if pair in top_namespaces:
        top_ns[pair].append(id)

# %%
top_ns
# Out:
# defaultdict(<type 'list'>, {(u'Probability theory and stochastic processes', u'Distribution theory'): [373, 1992, 2668, 4251, 4308, 6153, 9112], (u'Group theory and generalizations', u'Connections with homological algebra and category theory'): [1328, 2746, 4764, 4861, 6748, 7228, 7566], (u'Quantum theory', u'General mathematical topics and methods in quantum theory'): [1767, 2652, 6256, 6783, 8354, 8648, 9145], (u'Partial differential equations', u'Close-to-elliptic equations'): [1576, 1665, 3919, 4748, 5596, 5640, 7407, 7954, 8443], (u'Differential geometry', u'Classical differential geometry'): [2234, 2492, 3453, 5302, 6325, 7885, 7959], ('OTHER', u'Computational methods'): [1855, 2107, 3388, 3508, 4995, 8893], (u'Field theory and polynomials', u'Differential and difference algebra'): [228, 359, 2566, 5649, 6823, 7402, 7890, 8391, 8847], (u'Mathematical logic and foundations', u'General logic'): [1123, 2369, 5751, 6281, 7379, 8524, 9249], (u'Probability theory and stochastic processes', u'Foundations of probability theory'): [1009, 1366, 1926, 2044, 3979, 5325, 7416, 8265], (u'Game theory, economics, social and behavioral sciences', u'Mathematical economics'): [637, 698, 1652, 3432, 3580, 4768, 6259, 9058], (u'Optics, electromagnetic theory', u'General'): [1800, 2340, 2792, 2832, 4795, 7294, 9222], (u'Geometry', u'Analytic and descriptive geometry'): [616, 2316, 4620, 5099, 6033, 7151, 8608], (u'Fluid mechanics', u'Biological fluid mechanics'): [381, 1551, 2002, 2677, 4796, 5324, 5619, 7892, 9006, 9258], (u'Numerical analysis', u'Numerical linear algebra'): [36, 246, 3915, 4499, 5516, 6649, 9396], ('OTHER', u'Properties of specific nuclei listed by mass ranges (an additional heading must be chosen with these entries, where the given mass number limits are, to some degree, arbitrary)'): [2189, 2739, 4731, 4993, 6991, 7627, 8749]})

# %%
import cluster_evaluation
reload(cluster_evaluation)
evaluate = cluster_evaluation.Evaluator(doc_titles=titles, doc_ids=ids, 
                                        doc_ids_definitions=rels, doc_categories=doc_categories_list)

# %%
for (p, c), id_list in top_ns.items():
    print p, ': ', c
    
    evaluate.print_cluster(cluster_assignment, id_list, print_docs=0, sort_by_score=1, normalize_score=1, top_k_def=10)
    
    print 
    print
    print
# Out:
# Probability theory and stochastic processes :  Distribution theory
# common terms: ()
# top categories: (Probability distributions, 25), (Continuous distributions, 20), (Infinitely divisible probability distributions, 5), (Gaussian function, 5), (Exponential family distributions, 5)
# purity: 8.333
# relations:
# μ: mean* (1.00)
# σ: variance* (1.00)
# f: probability density function* (1.00)
# x: probability density function* (1.00)
# β: skewness parameter* (1.00)
# α: shape parameter* (0.99)
# X: random variable* (0.99)
# F: cumulative distribution function* (0.98)
# π: interval* (0.98)
# Γ: interval* (0.97)
#
#
#
# Group theory and generalizations :  Connections with homological algebra and category theory
# common terms: ()
# top categories: (Group theory, 30), (Abstract algebra, 19), (Metric geometry, 16), (Algebraic structures, 5), (Theorems in group theory, 4)
# purity: 10.000
# relations:
# G: group* (1.00)
# H: subgroup* (1.00)
# Z: group* (1.00)
# K: subgroup* (0.99)
# N: group* (0.99)
# p: power* (0.98)
# n: root* (0.95)
# F: free group* (0.95)
# Q: extension* (0.88)
# T: homomorphism* (0.72)
#
#
#
# Quantum theory :  General mathematical topics and methods in quantum theory
# common terms: ()
# top categories: (Quantum mechanics, 28), (Theoretical physics, 20), (Particle physics, 19), (Physics, 13), (Philosophy of physics, 12)
# purity: 9.333
# relations:
# z: direction* (1.00)
# p: momentum* (1.00)
# λ: wavelength* (1.00)
# t: time* (0.99)
# E: energy* (0.99)
# m: mass* (0.99)
# ρ: state* (0.98)
# ψ: pure state* (0.98)
# ℏ: angular momentum* (0.98)
# n: particles* (0.95)
#
#
#
# Partial differential equations :  Close-to-elliptic equations
# common terms: ()
# top categories: (Partial differential equations, 29), (Differential equations, 23), (Multivariable calculus, 18), (Mathematical analysis, 13), (Fluid dynamics, 7)
# purity: 9.667
# relations:
# Ω: domain* (1.00)
# t: time* (1.00)
# L: space* (1.00)
# p: space* (1.00)
# ω: angular frequency* (1.00)
# V: hilbert space* (0.99)
# D: domain* (0.98)
# u: horizontal velocity (0.96)
# x: time* (0.95)
# U: velocity profiles* (0.89)
#
#
#
# Differential geometry :  Classical differential geometry
# common terms: ()
# top categories: (Differential geometry, 27), (Differential topology, 17), (Mathematical analysis, 17), (Theoretical physics, 16), (Geometry, 14)
# purity: 3.375
# relations:
# M: manifold* (1.00)
# X: vector field* (1.00)
# γ: curve* (1.00)
# Y: vector field* (1.00)
# f: smooth function* (1.00)
# E: sections* (1.00)
# Q_Hur: order* (1.00)
# d: exterior derivative* (1.00)
# T: tangent bundle* (0.99)
# R: curvature* (0.98)
#
#
#
# OTHER :  Computational methods
# common terms: ()
# top categories: (General relativity, 17), (Exact solutions in general relativity, 9), (Equations, 9), (Theory of relativity, 7), (Theories of gravitation, 7)
# purity: 2.833
# relations:
# M: mass* (1.00)
# r_s: schwarzschild radius* (1.00)
# θ: colatitude (0.99)
# t: time* (0.99)
# T: tensor* (0.99)
# G: gravitational constant* (0.99)
# m: mass* (0.98)
# r: radius* (0.98)
# R: einstein tensor* (0.98)
# v: ingoing solution* (0.97)
#
#
#
# Field theory and polynomials :  Differential and difference algebra
# common terms: ()
# top categories: (Abstract algebra, 25), (Algebra, 20), (Functions and mappings, 11), (Polynomials, 11), (Analytic functions, 10)
# purity: 8.333
# relations:
# R: ring* (0.99)
# k: field* (0.95)
# D: city* (0.95)
# K: field* (0.95)
# x: polynomials (0.95)
# Γ: value group* (0.95)
# M: submodule* (0.95)
# n: matrix* (0.94)
# S: ring* (0.94)
# v: valuation* (0.89)
#
#
#
# Mathematical logic and foundations :  General logic
# common terms: ()
# top categories: (Mathematical logic, 21), (Logic, 11), (Proof theory, 11), (Syntax (logic), 10), (Formal systems, 9)
# purity: 3.000
# relations:
# w: world* (1.00)
# R: binary relation* (1.00)
# P: predicate* (1.00)
# Q: statement (0.95)
# W: nodes (0.94)
# ϕ: modal formula* (0.89)
# n: natural number (0.89)
# v: world* (0.88)
# T: relation* (0.88)
# k: degree (0.88)
#
#
#
# Probability theory and stochastic processes :  Foundations of probability theory
# common terms: ()
# top categories: (Stochastic processes, 33), (Probability theory, 31), (Statistics, 26), (Statistical data types, 23), (Measure theory, 8)
# purity: 11.000
# relations:
# X: process* (1.00)
# t: time* (1.00)
# X_t: process* (1.00)
# P: probability measure* (1.00)
# S: state space* (1.00)
# s: stochastic processe* (1.00)
# f: measurable function* (0.99)
# M: local martingale* (0.99)
# M_t: local martingale* (0.99)
# W_t: process* (0.98)
#
#
#
# Game theory, economics, social and behavioral sciences :  Mathematical economics
# common terms: ()
# top categories: (Economics, 12), (Financial economics, 11), (Microeconomics, 8), (Mathematical finance, 7), (Economic theories, 7)
# purity: 3.000
# relations:
# K: strike* (1.00)
# P: price level* (1.00)
# p: probability* (0.99)
# u: utility* (0.99)
# V: money* (0.99)
# M: money* (0.99)
# α: confidence level* (0.96)
# g: distortion function* (0.95)
# σ: volatility (0.95)
# R_f: return* (0.94)
#
#
#
# Optics, electromagnetic theory :  General
# common terms: ()
# top categories: (Optics, 17), (Electromagnetic radiation, 14), (Physical optics, 13), (Applied and interdisciplinary physics, 10), (Atomic, molecular, and optical physics, 10)
# purity: 5.667
# relations:
# λ: wavelength* (1.00)
# θ: angle* (1.00)
# n: refractive index* (1.00)
# z: direction* (1.00)
# E: electric field (1.00)
# θ_2: refraction* (1.00)
# ω: angular frequency* (0.99)
# k: wave number* (0.99)
# D: electric field* (0.99)
# N: slits (0.98)
#
#
#
# Geometry :  Analytic and descriptive geometry
# common terms: ()
# top categories: (Euclidean plane geometry, 14), (Polygons, 14), (Quadrilaterals, 9), (Triangle geometry, 9), (Euclidean geometry, 6)
# purity: 4.667
# relations:
# K: area (1.00)
# s: semiperimeter (1.00)
# p: diagonals (1.00)
# b: sides (1.00)
# x: distance* (1.00)
# q: diagonals (1.00)
# θ: angle* (1.00)
# R: circumradius* (1.00)
# r: inradius* (0.99)
# c: side* (0.99)
#
#
#
# Fluid mechanics :  Biological fluid mechanics
# common terms: ()
# top categories: (Fluid dynamics, 43), (Fluid mechanics, 35), (Dynamics, 30), (Aerodynamics, 15), (Partial differential equations, 10)
# purity: 8.600
# relations:
# ρ: density* (1.00)
# p: pressure* (1.00)
# g: acceleration* (1.00)
# k: wavenumber* (1.00)
# u: velocity* (1.00)
# v: velocity* (1.00)
# η: free surface* (1.00)
# ω: angular frequency* (1.00)
# z: free surface* (1.00)
# ν: kinematic viscosity* (1.00)
#
#
#
# Numerical analysis :  Numerical linear algebra
# common terms: ()
# top categories: (Linear algebra, 29), (Matrix theory, 20), (Numerical linear algebra, 11), (Algebra, 9), (Matrix decompositions, 9)
# purity: 5.800
# relations:
# B: matrix* (1.00)
# n: matrix* (1.00)
# m: matrix* (1.00)
# D: diagonal matrix* (1.00)
# Q: unitary matrix* (1.00)
# G: matrix* (0.99)
# r: rank* (0.99)
# T: matrix aa* (0.99)
# V: vector space* (0.99)
# λ_1: eigenvalues* (0.98)
#
#
#
# OTHER :  Properties of specific nuclei listed by mass ranges (an additional heading must be chosen with these entries, where the given mass number limits are, to some degree, arbitrary)
# common terms: ()
# top categories: (Physics, 25), (Theoretical physics, 21), (Quantum mechanics, 18), (Philosophy of physics, 18), (Particle physics, 18)
# purity: 3.125
# relations:
# m: mass* (1.00)
# U: time-evolution operator* (1.00)
# p: momentum operator* (0.99)
# V: potential* (0.99)
# t_0: time* (0.95)
# x: functional dependence* (0.95)
# q: charges* (0.95)
# Ψ: wavefunction (0.95)
# λ: exciton state* (0.95)
# H: hamiltonian (0.94)

# %%
for (p, c), id_list in top_ns.items():
    print (p, c)
    all_idx = np.array([], dtype=np.int)

    for cluster_id in id_list:
        indices, = np.where(cluster_assignment == cluster_id)
        all_idx = np.concatenate((all_idx, indices))
        
    all_articles = []
    for np_idx in all_idx:
        idx = int(np_idx)
        no_ids = sum(c for _, c in ids[idx].items())
        all_articles.append((idx, no_ids))
    
    all_articles = sorted(all_articles, key=lambda k: k[1], reverse=True)[:5]
    
    all_idx, _ = zip(*all_articles)
    
    for idx, size in all_articles:
        print '%s (%s),' % (titles[idx], size),
    
    print
    print
# Out:
# (u'Probability theory and stochastic processes', u'Distribution theory')
# Chebyshev's inequality (1019), Gamma distribution (612), Noncentral chi-squared distribution (435), Sum of normally distributed random variables (395), Chi-squared distribution (286),
#
# (u'Group theory and generalizations', u'Connections with homological algebra and category theory')
# Free abelian group (100), Center (group theory) (93), Holomorph (mathematics) (84), P-group (68), Powerful p-group (61),
#
# (u'Quantum theory', u'General mathematical topics and methods in quantum theory')
# Gamma matrices (1626), Schrödinger equation (959), Theoretical and experimental justification for the Schrödinger equation (547), Quantization of the electromagnetic field (535), Quantum harmonic oscillator (507),
#
# (u'Partial differential equations', u'Close-to-elliptic equations')
# Orr–Sommerfeld equation (256), Helmholtz equation (250), Fictitious domain method (214), Green's function for the three-variable Laplace equation (209), Eikonal equation (186),
#
# (u'Differential geometry', u'Classical differential geometry')
# Lie derivative (497), Riemannian connection on a surface (431), Connection form (390), Gauss–Codazzi equations (315), Ricci curvature (226),
#
# ('OTHER', u'Computational methods')
# Schwarzschild geodesics (1268), Newman–Penrose formalism (1118), Maxwell's equations in curved spacetime (958), Ricci calculus (800), Vaidya metric (563),
#
# (u'Field theory and polynomials', u'Differential and difference algebra')
# Recurrence relation (812), Spectral radius (514), Levi-Civita symbol (384), Perron–Frobenius theorem (364), Leibniz formula for determinants (334),
#
# (u'Mathematical logic and foundations', u'General logic')
# Sequent calculus (474), First-order logic (446), Original proof of Gödel's completeness theorem (415), Kripke semantics (294), Szpilrajn extension theorem (180),
#
# (u'Probability theory and stochastic processes', u'Foundations of probability theory')
# Wiener process (361), Itō calculus (249), Local martingale (202), Stratonovich integral (152), Glivenko–Cantelli theorem (136),
#
# (u'Game theory, economics, social and behavioral sciences', u'Mathematical economics')
# Modern portfolio theory (193), Lookback option (141), Binary option (126), Equation of exchange (118), Slutsky equation (93),
#
# (u'Optics, electromagnetic theory', u'General')
# Fraunhofer diffraction (mathematics) (1014), Diffraction formalism (532), Fourier optics (502), Second-harmonic generation (306), Mathematical descriptions of opacity (274),
#
# (u'Geometry', u'Analytic and descriptive geometry')
# Tangential quadrilateral (458), Quadrilateral (364), Bicentric quadrilateral (319), Cyclic quadrilateral (256), Brahmagupta's formula (224),
#
# (u'Fluid mechanics', u'Biological fluid mechanics')
# Navier–Stokes equations (961), Stokes wave (595), Airy wave theory (585), Mild-slope equation (562), Classic energy problem in open-channel flow (377),
#
# (u'Numerical analysis', u'Numerical linear algebra')
# Eigenvalues and eigenvectors (844), Singular value decomposition (796), Eigendecomposition of a matrix (446), Gauss–Seidel method (393), Diagonalizable matrix (320),
#
# ('OTHER', u'Properties of specific nuclei listed by mass ranges (an additional heading must be chosen with these entries, where the given mass number limits are, to some degree, arbitrary)')
# Operator (physics) (626), List of equations in quantum mechanics (623), Angular momentum operator (549), Dynamical pictures (quantum mechanics) (509), Hamiltonian (quantum mechanics) (437),

# %%
all_idx
# Out:
# (4656, 10447, 1076, 11115, 20959)

# %%
evaluate.find_identifier(cluster_assignment, purity_threshold=0.8, id=u'σ', min_size=3)
# Out:
# overall purity 0.6336
# number of high purity clusters of size at least 5 is 414
#
# category "Category theory", cluster_id=56, size=3:
# top categories: [(u'Category theory', 3), (u'Multilinear algebra', 3), (u'Monoidal categories', 3), (u'Closed categories', 1), (u'Dagger categories', 1)]
#      σ: (natural isomorphisms: 0.89)
# category "Physics", cluster_id=69, size=4:
# top categories: [(u'Physics', 4), (u'Mechanics', 3), (u'Theoretical physics', 3), (u'Modern physics', 2), (u'Philosophy of physics', 2)]
#      σ: (state: 1.94), (system: 0.87)
# category "Special functions", cluster_id=217, size=5:
# top categories: [(u'Special functions', 4), (u'Complex analysis', 3), (u'Types of functions', 2), (u'Mathematical analysis', 2), (u'Analytic functions', 2)]
#      σ: (standard deviation: 1.94), (variance: 1.90), (mean density*: 1.70), (expected value: 0.89), (errors: 0.87), (probability: 0.86), (normal distribution: 0.84), (distance: 0.81)
# category "Linear algebra", cluster_id=246, size=4:
# top categories: [(u'Linear algebra', 4), (u'Matrix theory', 4), (u'Multilinear algebra', 2), (u'Determinants', 2), (u'Matrices', 2)]
#      σ: (related permutation*: 2.83), (choice: 0.93), (l_fr_g: 0.86)
# category "Combinatorics", cluster_id=291, size=5:
# top categories: [(u'Combinatorics', 4), (u'Permutations', 3), (u'Enumerative combinatorics', 3), (u'Abstract algebra', 3), (u'Functions and mappings', 3)]
#      σ: (permutation: 2.93), (relative order: 0.91), (pattern: 0.84)
# category "Probability distributions", cluster_id=373, size=6:
# top categories: [(u'Probability distributions', 5), (u'Continuous distributions', 5), (u'Exponential family distributions', 3), (u'Normal distribution', 2), (u'Gaussian function', 2)]
#      σ: (variance*: 4.77), (means*: 1.63), (mode: 0.93), (interval: 0.91), (maximum pdf: 0.87), (standard deviation: 0.83)
# category "Mechanics", cluster_id=438, size=4:
# top categories: [(u'Mechanics', 4), (u'Modern physics', 4), (u'Philosophy of physics', 4), (u'Quantum mechanics', 4), (u'Solid state engineering', 4)]
#      σ: (scattering cross-section: 0.99)
# category "Measure theory", cluster_id=728, size=4:
# top categories: [(u'Measure theory', 4), (u'Measures (measure theory)', 3), (u'Mathematical analysis', 2), (u'Statistics', 1), (u'Stochastic processes', 1)]
#      σ: (variance: 0.95), (surface measure: 0.89)
# category "Stochastic processes", cluster_id=1366, size=4:
# top categories: [(u'Stochastic processes', 4), (u'Probability theory', 3), (u'Statistics', 2), (u'Martingale theory', 2), (u'Statistical data types', 2)]
#      σ: (infinitesimal variance: 0.99), (differentiable diffusion coefficient: 0.99), (drift: 0.83), (time-homogeneous itō diffusion: 0.83)
# category "Statistics", cluster_id=1448, size=4:
# top categories: [(u'Statistics', 4), (u'Data analysis', 4), (u'Estimation theory', 4), (u'Mathematical optimization', 4), (u'Statistical models', 4)]
#      σ: (variance: 1.79)
# category "Optics", cluster_id=1800, size=5:
# top categories: [(u'Optics', 4), (u'Electromagnetic radiation', 3), (u'Natural philosophy', 2), (u'Applied and interdisciplinary physics', 2), (u'Applied sciences', 2)]
#      σ: (conductivity: 0.96), (effects: 0.92), (properties: 0.86)
# category "Continuous distributions", cluster_id=1992, size=3:
# top categories: [(u'Continuous distributions', 3), (u'Probability distributions', 3), (u'Normal distribution', 3), (u'Gaussian function', 3), (u'Statistics', 1)]
#      σ: (variance: 3.64), (parametrization: 0.97), (issues: 0.88), (mean: 0.81)
# category "Quantum information science", cluster_id=2018, size=3:
# top categories: [(u'Quantum information science', 3), (u'Information theory', 3), (u'Quantum information theory', 3), (u'Thermodynamic entropy', 2), (u'Entropy and information', 2)]
#      σ: (state*: 1.79), (quantum states*: 1.73), (operators*: 1.67)
# category "General relativity", cluster_id=2107, size=4:
# top categories: [(u'General relativity', 4), (u'Astronomical objects', 2), (u'Theory of relativity', 2), (u'Density', 2), (u'Unsolved problems in physics', 2)]
#      σ: (shear: 0.95), (expansion: 0.89)
# category "Tensors", cluster_id=2296, size=3:
# top categories: [(u'Tensors', 3), (u'Coordinate systems', 2), (u'Cartography', 2), (u'Mathematical notation', 2), (u'Conceptual systems', 2)]
#      σ: (cauchy stress tensor: 0.99), (vector field: 0.89), (divergence: 0.83)
# category "Quantum mechanics", cluster_id=2652, size=4:
# top categories: [(u'Quantum mechanics', 4), (u'Quantum field theory', 4), (u'Theoretical physics', 4), (u'Particle physics', 4), (u'Spinors', 2)]
#      σ: (pauli matrices: 0.83)
# category "Fluid dynamics", cluster_id=2677, size=6:
# top categories: [(u'Fluid dynamics', 5), (u'Fluid mechanics', 4), (u'Dynamics', 4), (u'Partial differential equations', 3), (u'Equations of fluid dynamics', 2)]
#      σ: (unit area: 1.85), (corresponding stress fields: 0.99), (continuum: 0.95), (viscous force: 0.89), (stress tensor: 0.87)
# category "Mechanics", cluster_id=3040, size=8:
# top categories: [(u'Mechanics', 8), (u'Continuum mechanics', 7), (u'Materials science', 6), (u'Classical mechanics', 5), (u'Structural engineering', 3)]
#      σ: (stress: 0.97)
# category "Evidence-based practices", cluster_id=3442, size=3:
# top categories: [(u'Evidence-based practices', 3), (u'Public health', 3), (u'Epidemiology', 3), (u'Fields of application of statistics', 3), (u'Health sciences', 3)]
#      σ: (offspring distribution: 1.91), (variance: 0.83)
# category "Theory of relativity", cluster_id=3508, size=3:
# top categories: [(u'Theory of relativity', 3), (u'General relativity', 2), (u'Physical cosmology', 2), (u'Theories of gravitation', 2), (u'Mechanics', 1)]
#      σ: (shear: 0.93)
# category "Coordinate systems", cluster_id=3767, size=4:
# top categories: [(u'Coordinate systems', 4), (u'Cartography', 4), (u'Conceptual systems', 4), (u'Analytic geometry', 4), (u'Mathematical notation', 4)]
#      σ: (form: 1.85), (coordinate: 1.84), (curves: 1.74), (isosurface*: 1.66), (confocal parabolae: 0.93), (angle: 0.91), (self-intersecting torus: 0.86), (yellow crescent: 0.86), (blue paraboloid: 0.82)
# category "Signal processing", cluster_id=3934, size=6:
# top categories: [(u'Signal processing', 5), (u'Electrical engineering', 3), (u'Fourier analysis', 3), (u'Telecommunications engineering', 2), (u'Time series analysis', 2)]
#      σ: (real part: 0.96), (region: 0.93), (imaginary part: 0.93)
# category "Differential geometry", cluster_id=3975, size=5:
# top categories: [(u'Differential geometry', 5), (u'Fiber bundles', 4), (u'Topology', 4), (u'Algebraic topology', 4), (u'Differential topology', 3)]
#      σ: (boundary: 1.86), (detail: 0.87)
# category "Stochastic processes", cluster_id=3979, size=8:
# top categories: [(u'Stochastic processes', 8), (u'Statistics', 6), (u'Statistical data types', 6), (u'Probability theory', 6), (u'Martingale theory', 2)]
#      σ: (assets drift: 0.95), (volatility: 0.95)
# category "Theory of computation", cluster_id=4143, size=7:
# top categories: [(u'Theory of computation', 6), (u'Automata (computation)', 5), (u'Automata theory', 5), (u'Formal methods', 3), (u'Models of computation', 3)]
#      σ: (probability: 1.88), (string*: 1.81), (sentences: 0.83)
# category "Statistics", cluster_id=4160, size=3:
# top categories: [(u'Statistics', 3), (u'Statistical theory', 2), (u'Probability theory', 2), (u'Mathematical theorems', 2), (u'Asymptotic analysis', 1)]
#      σ: (mean: 1.81), (variance*: 1.76), (standard deviation: 0.89), (steps: 0.84)
# category "Probability distributions", cluster_id=4251, size=5:
# top categories: [(u'Probability distributions', 4), (u'Probability theory', 3), (u'Measure theory', 2), (u'Mathematical analysis', 2), (u'Theory of probability distributions', 2)]
#      σ: (standard deviation: 0.96), (central moment: 0.86)
# category "Linear algebra", cluster_id=4499, size=5:
# top categories: [(u'Linear algebra', 5), (u'Singular value decomposition', 3), (u'Algebra', 3), (u'Matrix decompositions', 3), (u'Matrix theory', 3)]
#      σ: (singular value: 2.72), (real number: 0.95)
# category "Stellar astronomy", cluster_id=4515, size=3:
# top categories: [(u'Stellar astronomy', 3), (u'Stars', 3), (u'Bodies of the Solar System', 2), (u'Sun', 2), (u'G-type main sequence stars', 2)]
#      σ: (stefan -- boltzmann constant*: 1.79), (matter: 0.95), (luminosity: 0.89)
# category "Mechanics", cluster_id=4557, size=4:
# top categories: [(u'Mechanics', 4), (u'Geotechnical engineering', 2), (u'Soil mechanics', 2), (u'Soil', 2), (u'Solid mechanics', 1)]
#      σ: (effective stress*: 3.85), (pore water pressure*: 1.77)
# category "Computer graphics algorithms", cluster_id=4681, size=3:
# top categories: [(u'Computer graphics algorithms', 3), (u'Computer graphics', 3), (u'Signal processing', 3), (u'Digital signal processing', 3), (u'Imaging', 3)]
#      σ: (right: 0.89)
# category "Fluid dynamics", cluster_id=4796, size=6:
# top categories: [(u'Fluid dynamics', 5), (u'Fluid mechanics', 5), (u'Dynamics', 5), (u'Aerodynamics', 3), (u'Physical quantities', 2)]
#      σ: (pressure: 0.87)
# category "Statistical data types", cluster_id=4866, size=3:
# top categories: [(u'Statistical data types', 3), (u'Multivariate statistics', 3), (u'Statistical classification', 2), (u'Machine learning', 2), (u'Algorithms', 2)]
#      σ: (scale parameters: 0.84)
# category "Materials science", cluster_id=4928, size=3:
# top categories: [(u'Materials science', 3), (u'Building engineering', 3), (u'Applied and interdisciplinary physics', 3), (u'Non-Newtonian fluids', 3), (u'Chemical engineering', 3)]
#      σ: (stress: 2.81), (strain: 1.85), (material: 1.77), (responses: 0.91), (maxwell: 0.81), (voigt: 0.81), (change: 0.80)
# category "Metric geometry", cluster_id=5100, size=5:
# top categories: [(u'Metric geometry', 4), (u'Differential geometry', 4), (u'Riemannian geometry', 3), (u'Differential topology', 3), (u'Topological spaces', 2)]
#      σ: (homeomorphisms: 0.99)
# category "Computer graphics algorithms", cluster_id=5207, size=3:
# top categories: [(u'Computer graphics algorithms', 3), (u'Computer graphics', 3), (u'Signal processing', 3), (u'Vision', 3), (u'Digital signal processing', 3)]
#      σ: (scale parameter*: 1.82)
# category "Differential geometry", cluster_id=5302, size=4:
# top categories: [(u'Differential geometry', 4), (u'Curves', 3), (u'Analytic geometry', 3), (u'Geometric shapes', 3), (u'Manifolds', 3)]
#      σ: (arclength parameter: 0.94), (curve: 0.86)
# category "Statistics", cluster_id=5389, size=20:
# top categories: [(u'Statistics', 17), (u'Econometrics', 16), (u'Statistical data types', 15), (u'Estimation theory', 14), (u'Regression analysis', 14)]
#      σ: (variance*: 8.38), (appropriate estimate*: 1.76), (radius: 0.99), (estimator: 0.95), (n-dimensional space: 0.95), (sample errors: 0.89), (gauss-markov theorem: 0.86), (covariance matrix: 0.86), (identity matrix: 0.85), (expected value: 0.83), (residual sum: 0.81), (mean: 0.81)
# category "Differential equations", cluster_id=5612, size=4:
# top categories: [(u'Differential equations', 4), (u'Stochastic processes', 3), (u'Stochastic differential equations', 3), (u'Partial differential equations', 2), (u'Multivariable calculus', 2)]
#      σ: (matrix field: 0.99)
# category "Fluid dynamics", cluster_id=5619, size=10:
# top categories: [(u'Fluid dynamics', 10), (u'Waves', 8), (u'Physical oceanography', 8), (u'Water waves', 8), (u'Fluid mechanics', 7)]
#      σ: (surface tension*: 3.51), (angular frequency: 1.82), (perturbation: 0.95), (frequencies: 0.84), (mean flow: 0.81)
# category "Electromagnetism", cluster_id=6026, size=12:
# top categories: [(u'Electromagnetism', 10), (u'Physics', 8), (u'Special relativity', 5), (u'Force', 5), (u'Electrodynamics', 4)]
#      σ: (conductivity: 1.87), (matrix: 0.96), (definition: 0.88)
# category "Arithmetic functions", cluster_id=6040, size=3:
# top categories: [(u'Arithmetic functions', 3), (u'Number theory', 3), (u'Types of functions', 2), (u'Multiplicative functions', 1), (u'Multilinear algebra', 1)]
#      σ: (divisor function: 0.89)
# category "Continuous distributions", cluster_id=6153, size=3:
# top categories: [(u'Continuous distributions', 3), (u'Probability distributions', 3), (u'Infinitely divisible probability distributions', 2), (u'Bayesian statistics', 2), (u'Probability distributions with non-finite variance', 2)]
#      σ: (known shape*: 1.82), (inverse gamma: 0.95)
# category "Force", cluster_id=6516, size=5:
# top categories: [(u'Force', 5), (u'Special relativity', 5), (u'Physics', 5), (u'Electromagnetism', 5), (u'Theory of relativity', 3)]
#      σ: (maxwell stress tensor: 0.99), (material: 0.95), (turn: 0.89), (electrical conductivity: 0.89)
# category "Numerical linear algebra", cluster_id=6649, size=3:
# top categories: [(u'Numerical linear algebra', 3), (u'Numerical analysis', 3), (u'Relaxation (iterative methods)', 3), (u'Iterative methods', 3), (u'Linear algebra', 3)]
#      σ: (step: 0.81)
# category "Fields of application of statistics", cluster_id=6894, size=3:
# top categories: [(u'Fields of application of statistics', 3), (u'Fields of finance', 2), (u'Financial markets', 2), (u'Derivatives (finance)', 2), (u'Mathematical finance', 2)]
#      σ: (constant volatility: 2.71), (security price: 0.86), (stock prices: 0.82)
# category "Materials science", cluster_id=6897, size=3:
# top categories: [(u'Materials science', 3), (u'Condensed matter physics', 3), (u'Electromagnetism', 2), (u'Matter', 2), (u'Physics', 2)]
#      σ: (satisfies: 0.99), (electrical conductivity: 0.99)
# category "Algorithms on strings", cluster_id=7395, size=6:
# top categories: [(u'Algorithms on strings', 6), (u'Substring indices', 4), (u'Database index techniques', 4), (u'Data structures', 4), (u'String (computer science)', 4)]
#      σ: (size: 1.86), (human genome: 0.89), (alphabet: 0.87)
# category "Stochastic processes", cluster_id=7416, size=9:
# top categories: [(u'Stochastic processes', 9), (u'Statistics', 8), (u'Probability theory', 8), (u'Statistical data types', 8), (u'Martingale theory', 2)]
#      σ: (variance: 0.96), (drift coefficient: 0.83)
# category "Celestial mechanics", cluster_id=7629, size=3:
# top categories: [(u'Celestial mechanics', 3), (u'Mechanics', 2), (u'Fields of mathematics', 2), (u'Dynamical systems', 2), (u'Solar System', 2)]
#      σ: (step: 0.99)
# category "Functional analysis", cluster_id=7900, size=3:
# top categories: [(u'Functional analysis', 3), (u'Algebra', 2), (u'Linear algebra', 2), (u'Functions and mappings', 2), (u'Mathematical analysis', 2)]
#      σ: (spectrum: 0.99)
# category "Differential geometry", cluster_id=7959, size=8:
# top categories: [(u'Differential geometry', 7), (u'Differential topology', 7), (u'Theoretical physics', 6), (u'Mathematical analysis', 5), (u'Geometry', 5)]
#      σ: (sections: 1.81), (representation: 0.87)
# category "Probability distributions", cluster_id=8064, size=7:
# top categories: [(u'Probability distributions', 7), (u'Probability theory', 5), (u'Types of probability distributions', 3), (u'Theory of probability distributions', 2), (u'Applied mathematics', 2)]
#      σ: (borel: 0.99), (probability space: 0.83)
# category "Electromagnetism", cluster_id=8112, size=3:
# top categories: [(u'Electromagnetism', 3), (u'Force', 2), (u'Special relativity', 2), (u'Physics', 2), (u'Dynamical systems', 1)]
#      σ: (electrical conductivity*: 2.67)
# category "Statistics", cluster_id=8246, size=3:
# top categories: [(u'Statistics', 3), (u'Statistical theory', 3), (u'Statistical deviation and dispersion', 2), (u'Estimation theory', 2), (u'Point estimation performance', 2)]
#      σ: (variance*: 3.70), (estimator*: 1.69), (square error: 0.83), (mean: 0.83)
# category "Statistics", cluster_id=8265, size=3:
# top categories: [(u'Statistics', 3), (u'Stochastic processes', 3), (u'Statistical data types', 3), (u'Probability theory', 3), (u'Fields of mathematics', 1)]
#      σ: (time: 0.99)
# category "Nuclear fusion", cluster_id=8628, size=3:
# top categories: [(u'Nuclear fusion', 3), (u'Fusion power', 3), (u'Plasma physics', 3), (u'Nuclear power', 3), (u'Astrophysics', 2)]
#      σ: (cross section: 0.83), (measure: 0.83)
# category "Quantum mechanics", cluster_id=8648, size=5:
# top categories: [(u'Quantum mechanics', 4), (u'Quantum field theory', 4), (u'Theoretical physics', 4), (u'Particle physics', 4), (u'Physics', 3)]
#      σ: (matrix operator: 0.87), (notation: 0.87)
# category "Special functions", cluster_id=8713, size=3:
# top categories: [(u'Special functions', 3), (u'Algebraic number theory', 3), (u'Analytic number theory', 3), (u'Zeta and L-functions', 3), (u'Conjectures', 2)]
#      σ: (divisor function: 0.95)
# category "Statistics", cluster_id=8733, size=4:
# top categories: [(u'Statistics', 4), (u'Inference', 1), (u'Prediction', 1), (u'Statements', 1), (u'Means', 1)]
#      σ: (standard deviation: 6.41), (sample*: 1.70), (variance: 0.99)
# category "Multilinear algebra", cluster_id=8847, size=3:
# top categories: [(u'Multilinear algebra', 3), (u'Algebra', 2), (u'Linear algebra', 2), (u'Theoretical physics', 2), (u'Differential geometry', 2)]
#      σ: (sign function: 0.99), (tuple: 0.86)
# category "Theoretical physics", cluster_id=8893, size=6:
# top categories: [(u'Theoretical physics', 5), (u'Differential geometry', 3), (u'Engineering concepts', 3), (u'Tensors', 3), (u'Multilinear algebra', 3)]
#      σ: (spacelike worldsheet coordinate*: 1.79)
# category "Continuum mechanics", cluster_id=8909, size=3:
# top categories: [(u'Continuum mechanics', 3), (u'Materials science', 3), (u'Solid mechanics', 3), (u'Fracture mechanics', 2), (u'Structural engineering', 2)]
#      σ: (applied stress*: 3.56), (strain energy release rate: 0.93), (curve: 0.89), (specimen dimensions: 0.89)
# category "Fluid dynamics", cluster_id=9006, size=6:
# top categories: [(u'Fluid dynamics', 5), (u'Fluid mechanics', 4), (u'Physics', 3), (u'Aerodynamics', 3), (u'Dynamics', 3)]
#      σ: (bulk viscosity*: 1.76), (expansion: 0.81)
# category "Continuous distributions", cluster_id=9045, size=5:
# top categories: [(u'Continuous distributions', 4), (u'Probability distributions', 4), (u'Extreme value data', 1), (u'Harmonic analysis', 1), (u'Mathematical analysis', 1)]
#      σ: (variance: 1.94), (shape parameters: 0.95)
# category "Derivatives (finance)", cluster_id=9058, size=4:
# top categories: [(u'Derivatives (finance)', 4), (u'Financial markets', 3), (u'Financial economics', 3), (u'Options', 3), (u'Investment', 2)]
#      σ: (volatility: 3.59), (risk-free interest rate*: 1.80), (account: 0.89), (diffusion: 0.83), (underlying asset: 0.82)
# category "Analysis of variance", cluster_id=9528, size=4:
# top categories: [(u'Analysis of variance', 4), (u'Least squares', 4), (u'Estimation theory', 4), (u'Numerical linear algebra', 4), (u'Mathematical optimization', 4)]
#      σ: (residual variance: 0.99)
# category "Probability theory", cluster_id=9557, size=4:
# top categories: [(u'Probability theory', 4), (u'Probability theorems', 3), (u'Theory of probability distributions', 2), (u'Statistics', 2), (u'Inequalities', 2)]
#      σ: (variance: 0.95)
# category "Coordinate systems", cluster_id=9598, size=3:
# top categories: [(u'Coordinate systems', 3), (u'Cartography', 3), (u'Conceptual systems', 3), (u'Analytic geometry', 3), (u'Mathematical notation', 3)]
#      σ: (coordinate: 1.84), (spheroids*: 1.69), (curves: 0.89), (red sphere: 0.86), (isosurface: 0.82)
# category "Programming language theory", cluster_id=9665, size=4:
# top categories: [(u'Programming language theory', 4), (u'Mathematical structures', 3), (u'Type theory', 3), (u'Logic in computer science', 3), (u'Mathematical logic', 3)]
#      σ: (variable name: 0.95), (pairs: 0.87), (type: 0.87)

# %% [markdown]
# ## Some statisitcs

# %%
len(desc_ids)
# Out:
# 414

# %%
used = sum((cluster_assignment == id).sum() for id in desc_ids)
used, len(ids), (len(ids) * 1.0 - used) / len(ids)
# Out:
# (1774, 22512, 0.9211975835110163)
